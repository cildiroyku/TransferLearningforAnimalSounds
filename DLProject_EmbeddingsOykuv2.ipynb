# %% [markdown]
# <a href="https://colab.research.google.com/github/cildiroyku/TransferLearningforAnimalSounds/blob/main/DLProject_EmbeddingsOyku.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch-vggish-yamnet #PyTorch wrapper library that lets you load and use YAMNet it gives pretrained YAMNet embeddings
# Out:
# Collecting torch-vggish-yamnet
#   Downloading torch_vggish_yamnet-0.2.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torch-vggish-yamnet) (2.0.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from torch-vggish-yamnet) (2.8.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from torch-vggish-yamnet) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->torch-vggish-yamnet) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->torch-vggish-yamnet) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->torch-vggish-yamnet) (3.0.3)
# Downloading torch_vggish_yamnet-0.2.1-py3-none-any.whl (10 kB)
# Installing collected packages: torch-vggish-yamnet
# Successfully installed torch-vggish-yamnet-0.2.1

# %%
#It downloads the ZIP file containing the ESC-50 dataset and extracts all the .wav audio files.
# !wget https://github.com/karoldvl/ESC-50/archive/master.zip
# !unzip master.zip -d ESC50
# Out:
# --2025-11-17 17:07:18--  https://github.com/karoldvl/ESC-50/archive/master.zip
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/karolpiczak/ESC-50/archive/master.zip [following]
# --2025-11-17 17:07:18--  https://github.com/karolpiczak/ESC-50/archive/master.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/karolpiczak/ESC-50/zip/refs/heads/master [following]
# --2025-11-17 17:07:18--  https://codeload.github.com/karolpiczak/ESC-50/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 20.205.243.165
# Connecting to codeload.github.com (codeload.github.com)|20.205.243.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 645695005 (616M) [application/zip]
# Saving to: ‘master.zip’
#
# master.zip          100%[===================>] 615.78M  17.9MB/s    in 38s
#
# 2025-11-17 17:07:57 (16.1 MB/s) - ‘master.zip’ saved [645695005/645695005]
#
# Archive:  master.zip
# 33c8ce9eb2cf0b1c2f8bcf322eb349b6be34dbb6
#    creating: ESC50/ESC-50-master/
#    creating: ESC50/ESC-50-master/.circleci/
#   inflating: ESC50/ESC-50-master/.circleci/config.yml
#    creating: ESC50/ESC-50-master/.github/
#   inflating: ESC50/ESC-50-master/.github/stale.yml
#  extracting: ESC50/ESC-50-master/.gitignore
#   inflating: ESC50/ESC-50-master/LICENSE
#   inflating: ESC50/ESC-50-master/README.md
#    creating: ESC50/ESC-50-master/audio/
#   inflating: ESC50/ESC-50-master/audio/1-100032-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/1-100038-A-14.wav
#   inflating: ESC50/ESC-50-master/audio/1-100210-A-36.wav
#   inflating: ESC50/ESC-50-master/audio/1-100210-B-36.wav
#   inflating: ESC50/ESC-50-master/audio/1-101296-A-19.wav
#   inflating: ESC50/ESC-50-master/audio/1-101296-B-19.wav
#   inflating: ESC50/ESC-50-master/audio/1-101336-A-30.wav
#   inflating: ESC50/ESC-50-master/audio/1-101404-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/1-103298-A-9.wav
#   inflating: ESC50/ESC-50-master/audio/1-103995-A-30.wav
#   inflating: ESC50/ESC-50-master/audio/1-103999-A-30.wav
#   inflating: ESC50/ESC-50-master/audio/1-104089-A-22.wav
#   inflating: ESC50/ESC-50-master/audio/1-104089-B-22.wav
#   inflating: ESC50/ESC-50-master/audio/1-105224-A-22.wav
#   inflating: ESC50/ESC-50-master/audio/1-110389-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/1-110537-A-22.wav
#   inflating: ESC50/ESC-50-master/audio/1-115521-A-19.wav
#   inflating: ESC50/ESC-50-master/audio/1-115545-A-48.wav
#   inflating: ESC50/ESC-50-master/audio/1-115545-B-48.wav
#   inflating: ESC50/ESC-50-master/audio/1-115545-C-48.wav
#   inflating: ESC50/ESC-50-master/audio/1-115546-A-48.wav
#   inflating: ESC50/ESC-50-master/audio/1-115920-A-22.wav
#   inflating: ESC50/ESC-50-master/audio/1-115920-B-22.wav
#   inflating: ESC50/ESC-50-master/audio/1-115921-A-22.wav
#   inflating: ESC50/ESC-50-master/audio/1-116765-A-41.wav
#   inflating: ESC50/ESC-50-master/audio/1-11687-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/1-118206-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/1-118559-A-17.wav
#   inflating: ESC50/ESC-50-master/audio/1-119125-A-45.wav
#   inflating: ESC50/ESC-50-master/audio/1-121951-A-8.wav
#   inflating: ESC50/ESC-50-master/audio/1-12653-A-15.wav
#   inflating: ESC50/ESC-50-master/audio/1-12654-A-15.wav
#   inflating: ESC50/ESC-50-master/audio/1-12654-B-15.wav
#   inflating: ESC50/ESC-50-master/audio/1-13571-A-46.wav
#   inflating: ESC50/ESC-50-master/audio/1-13572-A-46.wav
#   inflating: ESC50/ESC-50-master/audio/1-13613-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/1-137-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/1-137296-A-16.wav
#   inflating: ESC50/ESC-50-master/audio/1-14262-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/1-155858-A-25.wav
#   inflating: ESC50/ESC-50-master/audio/1-155858-B-25.wav
#   inflating: ESC50/ESC-50-master/audio/1-155858-C-25.wav
#   inflating: ESC50/ESC-50-master/audio/1-155858-D-25.wav
#   inflating: ESC50/ESC-50-master/audio/1-155858-E-25.wav
#   inflating: ESC50/ESC-50-master/audio/1-155858-F-25.wav
#   inflating: ESC50/ESC-50-master/audio/1-15689-A-4.wav
#   inflating: ESC50/ESC-50-master/audio/1-15689-B-4.wav
#   inflating: ESC50/ESC-50-master/audio/1-160563-A-48.wav
#   inflating: ESC50/ESC-50-master/audio/1-160563-B-48.wav
#   inflating: ESC50/ESC-50-master/audio/1-16568-A-3.wav
#   inflating: ESC50/ESC-50-master/audio/1-16746-A-15.wav
#   inflating: ESC50/ESC-50-master/audio/1-17092-A-27.wav
#   inflating: ESC50/ESC-50-master/audio/1-17092-B-27.wav
#   inflating: ESC50/ESC-50-master/audio/1-17124-A-43.wav
#   inflating: ESC50/ESC-50-master/audio/1-17150-A-12.wav
#   inflating: ESC50/ESC-50-master/audio/1-172649-A-40.wav
#   inflating: ESC50/ESC-50-master/audio/1-172649-B-40.wav
#   inflating: ESC50/ESC-50-master/audio/1-172649-C-40.wav
#   inflating: ESC50/ESC-50-master/audio/1-172649-D-40.wav
#   inflating: ESC50/ESC-50-master/audio/1-172649-E-40.wav
#   inflating: ESC50/ESC-50-master/audio/1-172649-F-40.wav
#   inflating: ESC50/ESC-50-master/audio/1-17295-A-29.wav
#   inflating: ESC50/ESC-50-master/audio/1-17367-A-10.wav
#   inflating: ESC50/ESC-50-master/audio/1-17565-A-12.wav
#   inflating: ESC50/ESC-50-master/audio/1-17585-A-7.wav
#   inflating: ESC50/ESC-50-master/audio/1-17742-A-12.wav
#   inflating: ESC50/ESC-50-master/audio/1-17808-A-12.wav
#   inflating: ESC50/ESC-50-master/audio/1-17808-B-12.wav
#   inflating: ESC50/ESC-50-master/audio/1-1791-A-26.wav
#   inflating: ESC50/ESC-50-master/audio/1-17970-A-4.wav
#   inflating: ESC50/ESC-50-master/audio/1-18074-A-6.wav
#   inflating: ESC50/ESC-50-master/audio/1-18074-B-6.wav
#   inflating: ESC50/ESC-50-master/audio/1-181071-A-40.wav
#   inflating: ESC50/ESC-50-master/audio/1-181071-B-40.wav
#   inflating: ESC50/ESC-50-master/audio/1-18527-A-44.wav
#   inflating: ESC50/ESC-50-master/audio/1-18527-B-44.wav
#   inflating: ESC50/ESC-50-master/audio/1-18631-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/1-18655-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/1-187207-A-20.wav
#   inflating: ESC50/ESC-50-master/audio/1-18755-A-4.wav
#   inflating: ESC50/ESC-50-master/audio/1-18755-B-4.wav
#   inflating: ESC50/ESC-50-master/audio/1-18757-A-4.wav
#   inflating: ESC50/ESC-50-master/audio/1-18810-A-49.wav
#   inflating: ESC50/ESC-50-master/audio/1-19026-A-43.wav
#   inflating: ESC50/ESC-50-master/audio/1-19111-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/1-19118-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/1-19501-A-7.wav
#   inflating: ESC50/ESC-50-master/audio/1-196660-A-8.wav
#   inflating: ESC50/ESC-50-master/audio/1-196660-B-8.wav
#   inflating: ESC50/ESC-50-master/audio/1-19840-A-36.wav
#   inflating: ESC50/ESC-50-master/audio/1-19872-A-36.wav
#   inflating: ESC50/ESC-50-master/audio/1-19872-B-36.wav
#   inflating: ESC50/ESC-50-master/audio/1-19898-A-41.wav
#   inflating: ESC50/ESC-50-master/audio/1-19898-B-41.wav
#   inflating: ESC50/ESC-50-master/audio/1-19898-C-41.wav
#   inflating: ESC50/ESC-50-master/audio/1-20133-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/1-202111-A-3.wav
#   inflating: ESC50/ESC-50-master/audio/1-20545-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/1-20736-A-18.wav
#   inflating: ESC50/ESC-50-master/audio/1-208757-A-2.wav
#   inflating: ESC50/ESC-50-master/audio/1-208757-B-2.wav
#   inflating: ESC50/ESC-50-master/audio/1-208757-C-2.wav
#   inflating: ESC50/ESC-50-master/audio/1-208757-D-2.wav
#   inflating: ESC50/ESC-50-master/audio/1-208757-E-2.wav
#   inflating: ESC50/ESC-50-master/audio/1-211527-A-20.wav
#   inflating: ESC50/ESC-50-master/audio/1-211527-B-20.wav
#   inflating: ESC50/ESC-50-master/audio/1-211527-C-20.wav
#   inflating: ESC50/ESC-50-master/audio/1-21189-A-10.wav
#   inflating: ESC50/ESC-50-master/audio/1-21421-A-46.wav
#   inflating: ESC50/ESC-50-master/audio/1-21896-A-35.wav
#   inflating: ESC50/ESC-50-master/audio/1-21934-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/1-21935-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/1-223162-A-25.wav
#   inflating: ESC50/ESC-50-master/audio/1-22694-A-20.wav
#   inflating: ESC50/ESC-50-master/audio/1-22694-B-20.wav
#   inflating: ESC50/ESC-50-master/audio/1-22804-A-46.wav
#   inflating: ESC50/ESC-50-master/audio/1-22882-A-44.wav
#   inflating: ESC50/ESC-50-master/audio/1-23094-A-15.wav
#   inflating: ESC50/ESC-50-master/audio/1-23094-B-15.wav
#   inflating: ESC50/ESC-50-master/audio/1-23222-A-19.wav
#   inflating: ESC50/ESC-50-master/audio/1-23222-B-19.wav
#   inflating: ESC50/ESC-50-master/audio/1-23706-A-49.wav
#   inflating: ESC50/ESC-50-master/audio/1-23996-A-35.wav
#   inflating: ESC50/ESC-50-master/audio/1-23996-B-35.wav
#   inflating: ESC50/ESC-50-master/audio/1-24074-A-43.wav
#   inflating: ESC50/ESC-50-master/audio/1-24076-A-43.wav
#   inflating: ESC50/ESC-50-master/audio/1-24524-A-19.wav
#   inflating: ESC50/ESC-50-master/audio/1-24524-B-19.wav
#   inflating: ESC50/ESC-50-master/audio/1-24524-C-19.wav
#   inflating: ESC50/ESC-50-master/audio/1-24796-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/1-254507-A-43.wav
#   inflating: ESC50/ESC-50-master/audio/1-25777-A-48.wav
#   inflating: ESC50/ESC-50-master/audio/1-25781-A-48.wav
#   inflating: ESC50/ESC-50-master/audio/1-260640-A-2.wav
#   inflating: ESC50/ESC-50-master/audio/1-260640-B-2.wav
#   inflating: ESC50/ESC-50-master/audio/1-260640-C-2.wav
#   inflating: ESC50/ESC-50-master/audio/1-26143-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/1-26176-A-43.wav
#   inflating: ESC50/ESC-50-master/audio/1-26177-A-43.wav
#   inflating: ESC50/ESC-50-master/audio/1-26188-A-30.wav
#   inflating: ESC50/ESC-50-master/audio/1-26222-A-10.wav
#   inflating: ESC50/ESC-50-master/audio/1-26806-A-1.wav
#   inflating: ESC50/ESC-50-master/audio/1-27165-A-35.wav
#   inflating: ESC50/ESC-50-master/audio/1-27166-A-35.wav
#   inflating: ESC50/ESC-50-master/audio/1-27403-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/1-27405-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/1-27724-A-1.wav
#   inflating: ESC50/ESC-50-master/audio/1-28005-A-18.wav
#   inflating: ESC50/ESC-50-master/audio/1-28135-A-11.wav
#   inflating: ESC50/ESC-50-master/audio/1-28135-B-11.wav
#   inflating: ESC50/ESC-50-master/audio/1-28808-A-43.wav
#   inflating: ESC50/ESC-50-master/audio/1-29532-A-16.wav
#   inflating: ESC50/ESC-50-master/audio/1-29561-A-10.wav
#   inflating: ESC50/ESC-50-master/audio/1-29680-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/1-30039-A-26.wav
#   inflating: ESC50/ESC-50-master/audio/1-30043-A-26.wav
#   inflating: ESC50/ESC-50-master/audio/1-30214-A-18.wav
#   inflating: ESC50/ESC-50-master/audio/1-30226-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/1-30344-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/1-30709-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/1-30709-B-23.wav
#   inflating: ESC50/ESC-50-master/audio/1-30709-C-23.wav
#   inflating: ESC50/ESC-50-master/audio/1-30830-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/1-31251-A-6.wav
#   inflating: ESC50/ESC-50-master/audio/1-31251-B-6.wav
#   inflating: ESC50/ESC-50-master/audio/1-31482-A-42.wav
#   inflating: ESC50/ESC-50-master/audio/1-31482-B-42.wav
#   inflating: ESC50/ESC-50-master/audio/1-31748-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/1-31836-A-4.wav
#   inflating: ESC50/ESC-50-master/audio/1-31836-B-4.wav
#   inflating: ESC50/ESC-50-master/audio/1-32318-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/1-32373-A-35.wav
#   inflating: ESC50/ESC-50-master/audio/1-32373-B-35.wav
#   inflating: ESC50/ESC-50-master/audio/1-32579-A-29.wav
#   inflating: ESC50/ESC-50-master/audio/1-33658-A-26.wav
#   inflating: ESC50/ESC-50-master/audio/1-34094-A-5.wav
#   inflating: ESC50/ESC-50-master/audio/1-34094-B-5.wav
#   inflating: ESC50/ESC-50-master/audio/1-34119-A-1.wav
#   inflating: ESC50/ESC-50-master/audio/1-34119-B-1.wav
#   inflating: ESC50/ESC-50-master/audio/1-34495-A-14.wav
#   inflating: ESC50/ESC-50-master/audio/1-34497-A-14.wav
#   inflating: ESC50/ESC-50-master/audio/1-34853-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/1-35687-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/1-36164-A-26.wav
#   inflating: ESC50/ESC-50-master/audio/1-36164-B-26.wav
#   inflating: ESC50/ESC-50-master/audio/1-36393-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/1-36397-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/1-36400-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/1-36402-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/1-36929-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/1-37226-A-29.wav
#   inflating: ESC50/ESC-50-master/audio/1-38559-A-14.wav
#   inflating: ESC50/ESC-50-master/audio/1-38560-A-14.wav
#   inflating: ESC50/ESC-50-master/audio/1-39835-A-9.wav
#   inflating: ESC50/ESC-50-master/audio/1-39835-B-9.wav
#   inflating: ESC50/ESC-50-master/audio/1-39901-A-11.wav
#   inflating: ESC50/ESC-50-master/audio/1-39901-B-11.wav
#   inflating: ESC50/ESC-50-master/audio/1-39923-A-1.wav
#   inflating: ESC50/ESC-50-master/audio/1-39937-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/1-40154-A-46.wav
#   inflating: ESC50/ESC-50-master/audio/1-40621-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/1-40730-A-1.wav
#   inflating: ESC50/ESC-50-master/audio/1-40967-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/1-41615-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/1-4211-A-12.wav
#   inflating: ESC50/ESC-50-master/audio/1-42139-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/1-43382-A-1.wav
#   inflating: ESC50/ESC-50-master/audio/1-43760-A-11.wav
#   inflating: ESC50/ESC-50-master/audio/1-43764-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/1-43807-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/1-43807-B-47.wav
#   inflating: ESC50/ESC-50-master/audio/1-43807-C-47.wav
#   inflating: ESC50/ESC-50-master/audio/1-43807-D-47.wav
#   inflating: ESC50/ESC-50-master/audio/1-44831-A-1.wav
#   inflating: ESC50/ESC-50-master/audio/1-45641-A-27.wav
#   inflating: ESC50/ESC-50-master/audio/1-45645-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/1-46040-A-14.wav
#   inflating: ESC50/ESC-50-master/audio/1-46272-A-12.wav
#   inflating: ESC50/ESC-50-master/audio/1-46274-A-18.wav
#   inflating: ESC50/ESC-50-master/audio/1-46353-A-49.wav
#   inflating: ESC50/ESC-50-master/audio/1-46744-A-36.wav
#   inflating: ESC50/ESC-50-master/audio/1-46938-A-7.wav
#   inflating: ESC50/ESC-50-master/audio/1-46938-B-7.wav
#   inflating: ESC50/ESC-50-master/audio/1-47250-A-41.wav
#   inflating: ESC50/ESC-50-master/audio/1-47250-B-41.wav
#   inflating: ESC50/ESC-50-master/audio/1-47273-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/1-47274-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/1-47709-A-16.wav
#   inflating: ESC50/ESC-50-master/audio/1-47714-A-16.wav
#   inflating: ESC50/ESC-50-master/audio/1-47819-A-5.wav
#   inflating: ESC50/ESC-50-master/audio/1-47819-B-5.wav
#   inflating: ESC50/ESC-50-master/audio/1-47819-C-5.wav
#   inflating: ESC50/ESC-50-master/audio/1-47923-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/1-48298-A-46.wav
#   inflating: ESC50/ESC-50-master/audio/1-48413-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/1-49098-A-35.wav
#   inflating: ESC50/ESC-50-master/audio/1-49409-A-8.wav
#   inflating: ESC50/ESC-50-master/audio/1-49409-B-8.wav
#   inflating: ESC50/ESC-50-master/audio/1-50060-A-10.wav
#   inflating: ESC50/ESC-50-master/audio/1-50454-A-44.wav
#   inflating: ESC50/ESC-50-master/audio/1-50455-A-44.wav
#   inflating: ESC50/ESC-50-master/audio/1-50623-A-15.wav
#   inflating: ESC50/ESC-50-master/audio/1-50625-A-17.wav
#   inflating: ESC50/ESC-50-master/audio/1-50661-A-44.wav
#   inflating: ESC50/ESC-50-master/audio/1-50688-A-17.wav
#   inflating: ESC50/ESC-50-master/audio/1-51035-A-16.wav
#   inflating: ESC50/ESC-50-master/audio/1-51036-A-16.wav
#   inflating: ESC50/ESC-50-master/audio/1-51037-A-16.wav
#   inflating: ESC50/ESC-50-master/audio/1-51147-A-25.wav
#   inflating: ESC50/ESC-50-master/audio/1-51170-A-18.wav
#   inflating: ESC50/ESC-50-master/audio/1-51433-A-17.wav
#   inflating: ESC50/ESC-50-master/audio/1-51436-A-17.wav
#   inflating: ESC50/ESC-50-master/audio/1-51805-A-33.wav
#   inflating: ESC50/ESC-50-master/audio/1-51805-B-33.wav
#   inflating: ESC50/ESC-50-master/audio/1-51805-C-33.wav
#   inflating: ESC50/ESC-50-master/audio/1-51805-D-33.wav
#   inflating: ESC50/ESC-50-master/audio/1-51805-E-33.wav
#   inflating: ESC50/ESC-50-master/audio/1-51805-F-33.wav
#   inflating: ESC50/ESC-50-master/audio/1-51805-G-33.wav
#   inflating: ESC50/ESC-50-master/audio/1-51805-H-33.wav
#   inflating: ESC50/ESC-50-master/audio/1-52266-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/1-52290-A-30.wav
#   inflating: ESC50/ESC-50-master/audio/1-52323-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/1-53444-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/1-53467-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/1-53501-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/1-53663-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/1-53670-A-18.wav
#   inflating: ESC50/ESC-50-master/audio/1-54065-A-45.wav
#   inflating: ESC50/ESC-50-master/audio/1-54065-B-45.wav
#   inflating: ESC50/ESC-50-master/audio/1-54084-A-42.wav
#   inflating: ESC50/ESC-50-master/audio/1-54505-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/1-54747-A-46.wav
#   inflating: ESC50/ESC-50-master/audio/1-54752-A-18.wav
#   inflating: ESC50/ESC-50-master/audio/1-54918-A-14.wav
#   inflating: ESC50/ESC-50-master/audio/1-54918-B-14.wav
#   inflating: ESC50/ESC-50-master/audio/1-54958-A-10.wav
#   inflating: ESC50/ESC-50-master/audio/1-56233-A-9.wav
#   inflating: ESC50/ESC-50-master/audio/1-56234-A-9.wav
#   inflating: ESC50/ESC-50-master/audio/1-56269-A-18.wav
#   inflating: ESC50/ESC-50-master/audio/1-56270-A-29.wav
#   inflating: ESC50/ESC-50-master/audio/1-56311-A-10.wav
#   inflating: ESC50/ESC-50-master/audio/1-56380-A-5.wav
#   inflating: ESC50/ESC-50-master/audio/1-56380-B-5.wav
#   inflating: ESC50/ESC-50-master/audio/1-56907-A-46.wav
#   inflating: ESC50/ESC-50-master/audio/1-57163-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/1-57316-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/1-57318-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/1-57795-A-8.wav
#   inflating: ESC50/ESC-50-master/audio/1-58277-A-3.wav
#   inflating: ESC50/ESC-50-master/audio/1-58792-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/1-58846-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/1-58923-A-27.wav
#   inflating: ESC50/ESC-50-master/audio/1-58923-B-27.wav
#   inflating: ESC50/ESC-50-master/audio/1-59102-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/1-59324-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/1-59513-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/1-5996-A-6.wav
#   inflating: ESC50/ESC-50-master/audio/1-60460-A-36.wav
#   inflating: ESC50/ESC-50-master/audio/1-60676-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/1-60997-A-20.wav
#   inflating: ESC50/ESC-50-master/audio/1-60997-B-20.wav
#   inflating: ESC50/ESC-50-master/audio/1-61212-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/1-61221-A-17.wav
#   inflating: ESC50/ESC-50-master/audio/1-61252-A-11.wav
#   inflating: ESC50/ESC-50-master/audio/1-61261-A-44.wav
#   inflating: ESC50/ESC-50-master/audio/1-61534-A-27.wav
#   inflating: ESC50/ESC-50-master/audio/1-62509-A-45.wav
#   inflating: ESC50/ESC-50-master/audio/1-62565-A-44.wav
#   inflating: ESC50/ESC-50-master/audio/1-62594-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/1-62849-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/1-62850-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/1-63679-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/1-63871-A-10.wav
#   inflating: ESC50/ESC-50-master/audio/1-64398-A-41.wav
#   inflating: ESC50/ESC-50-master/audio/1-64398-B-41.wav
#   inflating: ESC50/ESC-50-master/audio/1-64473-A-45.wav
#   inflating: ESC50/ESC-50-master/audio/1-65483-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/1-67033-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/1-67152-A-17.wav
#   inflating: ESC50/ESC-50-master/audio/1-67230-A-29.wav
#   inflating: ESC50/ESC-50-master/audio/1-67432-A-27.wav
#   inflating: ESC50/ESC-50-master/audio/1-68628-A-27.wav
#   inflating: ESC50/ESC-50-master/audio/1-68670-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/1-68734-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/1-69165-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/1-69422-A-3.wav
#   inflating: ESC50/ESC-50-master/audio/1-69641-A-3.wav
#   inflating: ESC50/ESC-50-master/audio/1-69760-A-16.wav
#   inflating: ESC50/ESC-50-master/audio/1-70300-A-45.wav
#   inflating: ESC50/ESC-50-master/audio/1-7057-A-12.wav
#   inflating: ESC50/ESC-50-master/audio/1-71030-A-6.wav
#   inflating: ESC50/ESC-50-master/audio/1-72195-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/1-72195-B-37.wav
#   inflating: ESC50/ESC-50-master/audio/1-72229-A-6.wav
#   inflating: ESC50/ESC-50-master/audio/1-72229-B-6.wav
#   inflating: ESC50/ESC-50-master/audio/1-72695-A-26.wav
#   inflating: ESC50/ESC-50-master/audio/1-73123-A-26.wav
#   inflating: ESC50/ESC-50-master/audio/1-73585-A-7.wav
#   inflating: ESC50/ESC-50-master/audio/1-74517-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/1-7456-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/1-75162-A-9.wav
#   inflating: ESC50/ESC-50-master/audio/1-75189-A-7.wav
#   inflating: ESC50/ESC-50-master/audio/1-75190-A-8.wav
#   inflating: ESC50/ESC-50-master/audio/1-76831-A-42.wav
#   inflating: ESC50/ESC-50-master/audio/1-76831-B-42.wav
#   inflating: ESC50/ESC-50-master/audio/1-76831-C-42.wav
#   inflating: ESC50/ESC-50-master/audio/1-76831-D-42.wav
#   inflating: ESC50/ESC-50-master/audio/1-76831-E-42.wav
#   inflating: ESC50/ESC-50-master/audio/1-77160-A-3.wav
#   inflating: ESC50/ESC-50-master/audio/1-77241-A-3.wav
#   inflating: ESC50/ESC-50-master/audio/1-79113-A-5.wav
#   inflating: ESC50/ESC-50-master/audio/1-79146-A-29.wav
#   inflating: ESC50/ESC-50-master/audio/1-79220-A-17.wav
#   inflating: ESC50/ESC-50-master/audio/1-79236-A-36.wav
#   inflating: ESC50/ESC-50-master/audio/1-79711-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/1-7973-A-7.wav
#   inflating: ESC50/ESC-50-master/audio/1-7974-A-49.wav
#   inflating: ESC50/ESC-50-master/audio/1-7974-B-49.wav
#   inflating: ESC50/ESC-50-master/audio/1-80785-A-7.wav
#   inflating: ESC50/ESC-50-master/audio/1-80840-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/1-80841-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/1-81001-A-30.wav
#   inflating: ESC50/ESC-50-master/audio/1-81001-B-30.wav
#   inflating: ESC50/ESC-50-master/audio/1-81269-A-3.wav
#   inflating: ESC50/ESC-50-master/audio/1-81851-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/1-81883-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/1-82817-A-30.wav
#   inflating: ESC50/ESC-50-master/audio/1-84393-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/1-84536-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/1-84704-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/1-84705-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/1-85123-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/1-85168-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/1-85184-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/1-85362-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/1-85909-A-29.wav
#   inflating: ESC50/ESC-50-master/audio/1-87565-A-29.wav
#   inflating: ESC50/ESC-50-master/audio/1-88409-A-45.wav
#   inflating: ESC50/ESC-50-master/audio/1-88409-B-45.wav
#   inflating: ESC50/ESC-50-master/audio/1-88574-A-8.wav
#   inflating: ESC50/ESC-50-master/audio/1-88807-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/1-90797-A-15.wav
#   inflating: ESC50/ESC-50-master/audio/1-91359-A-11.wav
#   inflating: ESC50/ESC-50-master/audio/1-91359-B-11.wav
#   inflating: ESC50/ESC-50-master/audio/1-94036-A-22.wav
#   inflating: ESC50/ESC-50-master/audio/1-94231-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/1-94231-B-32.wav
#   inflating: ESC50/ESC-50-master/audio/1-95563-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/1-96890-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/1-96950-A-9.wav
#   inflating: ESC50/ESC-50-master/audio/1-96950-B-9.wav
#   inflating: ESC50/ESC-50-master/audio/1-97392-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/1-977-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/1-97793-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/1-9841-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/1-9886-A-49.wav
#   inflating: ESC50/ESC-50-master/audio/1-9887-A-49.wav
#   inflating: ESC50/ESC-50-master/audio/1-9887-B-49.wav
#   inflating: ESC50/ESC-50-master/audio/1-99958-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/2-100648-A-43.wav
#   inflating: ESC50/ESC-50-master/audio/2-100786-A-1.wav
#   inflating: ESC50/ESC-50-master/audio/2-101676-A-10.wav
#   inflating: ESC50/ESC-50-master/audio/2-102414-A-17.wav
#   inflating: ESC50/ESC-50-master/audio/2-102414-B-17.wav
#   inflating: ESC50/ESC-50-master/audio/2-102414-C-17.wav
#   inflating: ESC50/ESC-50-master/audio/2-102414-D-17.wav
#   inflating: ESC50/ESC-50-master/audio/2-102414-E-17.wav
#   inflating: ESC50/ESC-50-master/audio/2-102414-F-17.wav
#   inflating: ESC50/ESC-50-master/audio/2-102414-G-17.wav
#   inflating: ESC50/ESC-50-master/audio/2-102435-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/2-102567-A-35.wav
#   inflating: ESC50/ESC-50-master/audio/2-102567-B-35.wav
#   inflating: ESC50/ESC-50-master/audio/2-102567-C-35.wav
#   inflating: ESC50/ESC-50-master/audio/2-102567-D-35.wav
#   inflating: ESC50/ESC-50-master/audio/2-102568-A-35.wav
#   inflating: ESC50/ESC-50-master/audio/2-102581-A-29.wav
#   inflating: ESC50/ESC-50-master/audio/2-102581-B-29.wav
#   inflating: ESC50/ESC-50-master/audio/2-102852-A-11.wav
#   inflating: ESC50/ESC-50-master/audio/2-103423-A-3.wav
#   inflating: ESC50/ESC-50-master/audio/2-103424-A-3.wav
#   inflating: ESC50/ESC-50-master/audio/2-103426-A-3.wav
#   inflating: ESC50/ESC-50-master/audio/2-103427-A-3.wav
#   inflating: ESC50/ESC-50-master/audio/2-103428-A-3.wav
#   inflating: ESC50/ESC-50-master/audio/2-104105-A-19.wav
#   inflating: ESC50/ESC-50-master/audio/2-104105-B-19.wav
#   inflating: ESC50/ESC-50-master/audio/2-104168-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/2-104475-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/2-104476-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/2-104877-A-3.wav
#   inflating: ESC50/ESC-50-master/audio/2-104952-A-16.wav
#   inflating: ESC50/ESC-50-master/audio/2-104952-B-16.wav
#   inflating: ESC50/ESC-50-master/audio/2-105270-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/2-106014-A-44.wav
#   inflating: ESC50/ESC-50-master/audio/2-106015-A-44.wav
#   inflating: ESC50/ESC-50-master/audio/2-106015-B-44.wav
#   inflating: ESC50/ESC-50-master/audio/2-106019-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/2-106072-A-36.wav
#   inflating: ESC50/ESC-50-master/audio/2-106073-A-36.wav
#   inflating: ESC50/ESC-50-master/audio/2-106486-A-44.wav
#   inflating: ESC50/ESC-50-master/audio/2-106487-A-44.wav
#   inflating: ESC50/ESC-50-master/audio/2-106849-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/2-106881-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/2-107228-A-44.wav
#   inflating: ESC50/ESC-50-master/audio/2-107228-B-44.wav
#   inflating: ESC50/ESC-50-master/audio/2-107351-A-20.wav
#   inflating: ESC50/ESC-50-master/audio/2-107351-B-20.wav
#   inflating: ESC50/ESC-50-master/audio/2-108017-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/2-108760-A-14.wav
#   inflating: ESC50/ESC-50-master/audio/2-108760-B-14.wav
#   inflating: ESC50/ESC-50-master/audio/2-108761-A-14.wav
#   inflating: ESC50/ESC-50-master/audio/2-108763-A-9.wav
#   inflating: ESC50/ESC-50-master/audio/2-108766-A-9.wav
#   inflating: ESC50/ESC-50-master/audio/2-108767-A-9.wav
#   inflating: ESC50/ESC-50-master/audio/2-108767-B-9.wav
#   inflating: ESC50/ESC-50-master/audio/2-108767-C-9.wav
#   inflating: ESC50/ESC-50-master/audio/2-109231-A-9.wav
#   inflating: ESC50/ESC-50-master/audio/2-109231-B-9.wav
#   inflating: ESC50/ESC-50-master/audio/2-109231-C-9.wav
#   inflating: ESC50/ESC-50-master/audio/2-109316-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/2-109371-A-16.wav
#   inflating: ESC50/ESC-50-master/audio/2-109371-B-16.wav
#   inflating: ESC50/ESC-50-master/audio/2-109371-C-16.wav
#   inflating: ESC50/ESC-50-master/audio/2-109371-D-16.wav
#   inflating: ESC50/ESC-50-master/audio/2-109374-A-16.wav
#   inflating: ESC50/ESC-50-master/audio/2-109505-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/2-109759-A-26.wav
#   inflating: ESC50/ESC-50-master/audio/2-109759-B-26.wav
#   inflating: ESC50/ESC-50-master/audio/2-110010-A-5.wav
#   inflating: ESC50/ESC-50-master/audio/2-110011-A-5.wav
#   inflating: ESC50/ESC-50-master/audio/2-110417-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/2-110417-B-28.wav
#   inflating: ESC50/ESC-50-master/audio/2-110613-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/2-110614-A-8.wav
#   inflating: ESC50/ESC-50-master/audio/2-110614-B-8.wav
#   inflating: ESC50/ESC-50-master/audio/2-112213-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/2-112213-B-39.wav
#   inflating: ESC50/ESC-50-master/audio/2-114254-A-30.wav
#   inflating: ESC50/ESC-50-master/audio/2-114280-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/2-114587-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/2-114609-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/2-114609-B-28.wav
#   inflating: ESC50/ESC-50-master/audio/2-116400-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/2-117116-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/2-117271-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/2-117330-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/2-117615-A-48.wav
#   inflating: ESC50/ESC-50-master/audio/2-117615-B-48.wav
#   inflating: ESC50/ESC-50-master/audio/2-117615-C-48.wav
#   inflating: ESC50/ESC-50-master/audio/2-117615-D-48.wav
#   inflating: ESC50/ESC-50-master/audio/2-117615-E-48.wav
#   inflating: ESC50/ESC-50-master/audio/2-117616-A-48.wav
#   inflating: ESC50/ESC-50-master/audio/2-117617-A-48.wav
#   inflating: ESC50/ESC-50-master/audio/2-117625-A-10.wav
#   inflating: ESC50/ESC-50-master/audio/2-117795-A-3.wav
#   inflating: ESC50/ESC-50-master/audio/2-117795-B-3.wav
#   inflating: ESC50/ESC-50-master/audio/2-118072-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/2-118104-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/2-118459-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/2-118459-B-32.wav
#   inflating: ESC50/ESC-50-master/audio/2-118624-A-30.wav
#   inflating: ESC50/ESC-50-master/audio/2-118625-A-30.wav
#   inflating: ESC50/ESC-50-master/audio/2-118817-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/2-118964-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/2-119102-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/2-119139-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/2-119161-A-8.wav
#   inflating: ESC50/ESC-50-master/audio/2-119161-B-8.wav
#   inflating: ESC50/ESC-50-master/audio/2-119161-C-8.wav
#   inflating: ESC50/ESC-50-master/audio/2-119748-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/2-120218-A-30.wav
#   inflating: ESC50/ESC-50-master/audio/2-120218-B-30.wav
#   inflating: ESC50/ESC-50-master/audio/2-120333-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/2-120586-A-6.wav
#   inflating: ESC50/ESC-50-master/audio/2-120587-A-6.wav
#   inflating: ESC50/ESC-50-master/audio/2-121909-A-35.wav
#   inflating: ESC50/ESC-50-master/audio/2-121978-A-29.wav
#   inflating: ESC50/ESC-50-master/audio/2-122066-A-45.wav
#   inflating: ESC50/ESC-50-master/audio/2-122066-B-45.wav
#   inflating: ESC50/ESC-50-master/audio/2-122067-A-45.wav
#   inflating: ESC50/ESC-50-master/audio/2-122067-B-45.wav
#   inflating: ESC50/ESC-50-master/audio/2-122104-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/2-122104-B-0.wav
#   inflating: ESC50/ESC-50-master/audio/2-122616-A-14.wav
#   inflating: ESC50/ESC-50-master/audio/2-122763-A-29.wav
#   inflating: ESC50/ESC-50-master/audio/2-122763-B-29.wav
#   inflating: ESC50/ESC-50-master/audio/2-122820-A-36.wav
#   inflating: ESC50/ESC-50-master/audio/2-122820-B-36.wav
#   inflating: ESC50/ESC-50-master/audio/2-123712-A-33.wav
#   inflating: ESC50/ESC-50-master/audio/2-123896-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/2-124564-A-15.wav
#   inflating: ESC50/ESC-50-master/audio/2-124662-A-11.wav
#   inflating: ESC50/ESC-50-master/audio/2-125520-A-43.wav
#   inflating: ESC50/ESC-50-master/audio/2-125821-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/2-125875-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/2-125966-A-11.wav
#   inflating: ESC50/ESC-50-master/audio/2-126433-A-17.wav
#   inflating: ESC50/ESC-50-master/audio/2-126756-A-29.wav
#   inflating: ESC50/ESC-50-master/audio/2-127108-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/2-127109-A-6.wav
#   inflating: ESC50/ESC-50-master/audio/2-128465-A-43.wav
#   inflating: ESC50/ESC-50-master/audio/2-128465-B-43.wav
#   inflating: ESC50/ESC-50-master/audio/2-128631-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/2-130245-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/2-130978-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/2-130979-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/2-131943-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/2-132157-A-11.wav
#   inflating: ESC50/ESC-50-master/audio/2-132157-B-11.wav
#   inflating: ESC50/ESC-50-master/audio/2-133863-A-11.wav
#   inflating: ESC50/ESC-50-master/audio/2-133889-A-30.wav
#   inflating: ESC50/ESC-50-master/audio/2-134049-A-6.wav
#   inflating: ESC50/ESC-50-master/audio/2-134700-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/2-134915-A-30.wav
#   inflating: ESC50/ESC-50-master/audio/2-135649-A-45.wav
#   inflating: ESC50/ESC-50-master/audio/2-135649-B-45.wav
#   inflating: ESC50/ESC-50-master/audio/2-135649-C-45.wav
#   inflating: ESC50/ESC-50-master/audio/2-135728-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/2-135860-A-49.wav
#   inflating: ESC50/ESC-50-master/audio/2-137162-A-11.wav
#   inflating: ESC50/ESC-50-master/audio/2-138257-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/2-138465-A-43.wav
#   inflating: ESC50/ESC-50-master/audio/2-139748-A-15.wav
#   inflating: ESC50/ESC-50-master/audio/2-139748-B-15.wav
#   inflating: ESC50/ESC-50-master/audio/2-139749-A-15.wav
#   inflating: ESC50/ESC-50-master/audio/2-140147-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/2-140841-A-30.wav
#   inflating: ESC50/ESC-50-master/audio/2-141563-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/2-141584-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/2-141681-A-36.wav
#   inflating: ESC50/ESC-50-master/audio/2-141681-B-36.wav
#   inflating: ESC50/ESC-50-master/audio/2-141682-A-36.wav
#   inflating: ESC50/ESC-50-master/audio/2-141682-B-36.wav
#   inflating: ESC50/ESC-50-master/audio/2-144031-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/2-144137-A-43.wav
#   inflating: ESC50/ESC-50-master/audio/2-146877-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/2-146877-B-31.wav
#   inflating: ESC50/ESC-50-master/audio/2-151079-A-20.wav
#   inflating: ESC50/ESC-50-master/audio/2-152895-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/2-152964-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/2-153388-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/2-154688-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/2-155801-A-11.wav
#   inflating: ESC50/ESC-50-master/audio/2-157488-A-6.wav
#   inflating: ESC50/ESC-50-master/audio/2-158746-A-2.wav
#   inflating: ESC50/ESC-50-master/audio/2-158746-B-2.wav
#   inflating: ESC50/ESC-50-master/audio/2-158746-C-2.wav
#   inflating: ESC50/ESC-50-master/audio/2-158746-D-2.wav
#   inflating: ESC50/ESC-50-master/audio/2-160128-A-7.wav
#   inflating: ESC50/ESC-50-master/audio/2-160888-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/2-165801-A-48.wav
#   inflating: ESC50/ESC-50-master/audio/2-166644-A-2.wav
#   inflating: ESC50/ESC-50-master/audio/2-166644-B-2.wav
#   inflating: ESC50/ESC-50-master/audio/2-166644-C-2.wav
#   inflating: ESC50/ESC-50-master/audio/2-173559-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/2-173607-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/2-173618-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/2-182508-A-8.wav
#   inflating: ESC50/ESC-50-master/audio/2-182508-B-8.wav
#   inflating: ESC50/ESC-50-master/audio/2-184077-A-49.wav
#   inflating: ESC50/ESC-50-master/audio/2-18766-A-12.wav
#   inflating: ESC50/ESC-50-master/audio/2-18766-B-12.wav
#   inflating: ESC50/ESC-50-master/audio/2-188822-A-40.wav
#   inflating: ESC50/ESC-50-master/audio/2-188822-B-40.wav
#   inflating: ESC50/ESC-50-master/audio/2-188822-C-40.wav
#   inflating: ESC50/ESC-50-master/audio/2-188822-D-40.wav
#   inflating: ESC50/ESC-50-master/audio/2-196688-A-8.wav
#   inflating: ESC50/ESC-50-master/audio/2-205966-A-16.wav
#   inflating: ESC50/ESC-50-master/audio/2-209471-A-25.wav
#   inflating: ESC50/ESC-50-master/audio/2-209472-A-25.wav
#   inflating: ESC50/ESC-50-master/audio/2-209473-A-25.wav
#   inflating: ESC50/ESC-50-master/audio/2-209474-A-25.wav
#   inflating: ESC50/ESC-50-master/audio/2-209475-A-25.wav
#   inflating: ESC50/ESC-50-master/audio/2-209476-A-25.wav
#   inflating: ESC50/ESC-50-master/audio/2-209477-A-25.wav
#   inflating: ESC50/ESC-50-master/audio/2-209478-A-25.wav
#   inflating: ESC50/ESC-50-master/audio/2-250710-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/2-25292-A-22.wav
#   inflating: ESC50/ESC-50-master/audio/2-25293-A-22.wav
#   inflating: ESC50/ESC-50-master/audio/2-262579-A-45.wav
#   inflating: ESC50/ESC-50-master/audio/2-28314-A-12.wav
#   inflating: ESC50/ESC-50-master/audio/2-28314-B-12.wav
#   inflating: ESC50/ESC-50-master/audio/2-30322-A-12.wav
#   inflating: ESC50/ESC-50-master/audio/2-30322-B-12.wav
#   inflating: ESC50/ESC-50-master/audio/2-32515-A-4.wav
#   inflating: ESC50/ESC-50-master/audio/2-32515-B-4.wav
#   inflating: ESC50/ESC-50-master/audio/2-32515-C-4.wav
#   inflating: ESC50/ESC-50-master/audio/2-32515-D-4.wav
#   inflating: ESC50/ESC-50-master/audio/2-32834-A-4.wav
#   inflating: ESC50/ESC-50-master/audio/2-37806-A-40.wav
#   inflating: ESC50/ESC-50-master/audio/2-37806-B-40.wav
#   inflating: ESC50/ESC-50-master/audio/2-37806-C-40.wav
#   inflating: ESC50/ESC-50-master/audio/2-37806-D-40.wav
#   inflating: ESC50/ESC-50-master/audio/2-37870-A-2.wav
#   inflating: ESC50/ESC-50-master/audio/2-39441-A-19.wav
#   inflating: ESC50/ESC-50-master/audio/2-39443-A-19.wav
#   inflating: ESC50/ESC-50-master/audio/2-39443-B-19.wav
#   inflating: ESC50/ESC-50-master/audio/2-39945-A-19.wav
#   inflating: ESC50/ESC-50-master/audio/2-39945-B-19.wav
#   inflating: ESC50/ESC-50-master/audio/2-39945-C-19.wav
#   inflating: ESC50/ESC-50-master/audio/2-42101-A-43.wav
#   inflating: ESC50/ESC-50-master/audio/2-43802-A-42.wav
#   inflating: ESC50/ESC-50-master/audio/2-43806-A-42.wav
#   inflating: ESC50/ESC-50-master/audio/2-50665-A-20.wav
#   inflating: ESC50/ESC-50-master/audio/2-50666-A-20.wav
#   inflating: ESC50/ESC-50-master/audio/2-50667-A-41.wav
#   inflating: ESC50/ESC-50-master/audio/2-50667-B-41.wav
#   inflating: ESC50/ESC-50-master/audio/2-50668-A-41.wav
#   inflating: ESC50/ESC-50-master/audio/2-50668-B-41.wav
#   inflating: ESC50/ESC-50-master/audio/2-50774-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/2-51173-A-35.wav
#   inflating: ESC50/ESC-50-master/audio/2-51630-A-49.wav
#   inflating: ESC50/ESC-50-master/audio/2-51630-B-49.wav
#   inflating: ESC50/ESC-50-master/audio/2-52001-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/2-52001-B-28.wav
#   inflating: ESC50/ESC-50-master/audio/2-52085-A-4.wav
#   inflating: ESC50/ESC-50-master/audio/2-52085-B-4.wav
#   inflating: ESC50/ESC-50-master/audio/2-52789-A-4.wav
#   inflating: ESC50/ESC-50-master/audio/2-54086-A-43.wav
#   inflating: ESC50/ESC-50-master/audio/2-54961-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/2-54962-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/2-56926-A-46.wav
#   inflating: ESC50/ESC-50-master/audio/2-57191-A-46.wav
#   inflating: ESC50/ESC-50-master/audio/2-57733-A-22.wav
#   inflating: ESC50/ESC-50-master/audio/2-59241-A-35.wav
#   inflating: ESC50/ESC-50-master/audio/2-59321-A-49.wav
#   inflating: ESC50/ESC-50-master/audio/2-59565-A-46.wav
#   inflating: ESC50/ESC-50-master/audio/2-59566-A-46.wav
#   inflating: ESC50/ESC-50-master/audio/2-60180-A-49.wav
#   inflating: ESC50/ESC-50-master/audio/2-60180-B-49.wav
#   inflating: ESC50/ESC-50-master/audio/2-60791-A-26.wav
#   inflating: ESC50/ESC-50-master/audio/2-60794-A-26.wav
#   inflating: ESC50/ESC-50-master/audio/2-60795-A-26.wav
#   inflating: ESC50/ESC-50-master/audio/2-60900-A-22.wav
#   inflating: ESC50/ESC-50-master/audio/2-61311-A-12.wav
#   inflating: ESC50/ESC-50-master/audio/2-61618-A-46.wav
#   inflating: ESC50/ESC-50-master/audio/2-62226-A-26.wav
#   inflating: ESC50/ESC-50-master/audio/2-64332-A-18.wav
#   inflating: ESC50/ESC-50-master/audio/2-64962-A-15.wav
#   inflating: ESC50/ESC-50-master/audio/2-64963-A-15.wav
#   inflating: ESC50/ESC-50-master/audio/2-65484-A-18.wav
#   inflating: ESC50/ESC-50-master/audio/2-65747-A-12.wav
#   inflating: ESC50/ESC-50-master/audio/2-65750-A-1.wav
#   inflating: ESC50/ESC-50-master/audio/2-66205-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/2-66637-A-20.wav
#   inflating: ESC50/ESC-50-master/audio/2-66637-B-20.wav
#   inflating: ESC50/ESC-50-master/audio/2-67422-A-18.wav
#   inflating: ESC50/ESC-50-master/audio/2-68391-A-41.wav
#   inflating: ESC50/ESC-50-master/audio/2-68391-B-41.wav
#   inflating: ESC50/ESC-50-master/audio/2-68595-A-15.wav
#   inflating: ESC50/ESC-50-master/audio/2-68595-B-15.wav
#   inflating: ESC50/ESC-50-master/audio/2-69131-A-5.wav
#   inflating: ESC50/ESC-50-master/audio/2-69131-B-5.wav
#   inflating: ESC50/ESC-50-master/audio/2-70052-A-42.wav
#   inflating: ESC50/ESC-50-master/audio/2-70052-B-42.wav
#   inflating: ESC50/ESC-50-master/audio/2-70280-A-18.wav
#   inflating: ESC50/ESC-50-master/audio/2-70344-A-33.wav
#   inflating: ESC50/ESC-50-master/audio/2-70366-A-33.wav
#   inflating: ESC50/ESC-50-master/audio/2-70367-A-33.wav
#   inflating: ESC50/ESC-50-master/audio/2-70936-A-42.wav
#   inflating: ESC50/ESC-50-master/audio/2-70938-A-42.wav
#   inflating: ESC50/ESC-50-master/audio/2-70939-A-42.wav
#   inflating: ESC50/ESC-50-master/audio/2-71162-A-1.wav
#   inflating: ESC50/ESC-50-master/audio/2-72268-A-6.wav
#   inflating: ESC50/ESC-50-master/audio/2-72547-A-14.wav
#   inflating: ESC50/ESC-50-master/audio/2-72547-B-14.wav
#   inflating: ESC50/ESC-50-master/audio/2-72547-C-14.wav
#   inflating: ESC50/ESC-50-master/audio/2-72547-D-14.wav
#   inflating: ESC50/ESC-50-master/audio/2-72677-A-18.wav
#   inflating: ESC50/ESC-50-master/audio/2-72688-A-42.wav
#   inflating: ESC50/ESC-50-master/audio/2-72970-A-10.wav
#   inflating: ESC50/ESC-50-master/audio/2-73027-A-10.wav
#   inflating: ESC50/ESC-50-master/audio/2-7321-A-33.wav
#   inflating: ESC50/ESC-50-master/audio/2-73260-A-10.wav
#   inflating: ESC50/ESC-50-master/audio/2-73544-A-27.wav
#   inflating: ESC50/ESC-50-master/audio/2-74361-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/2-74977-A-18.wav
#   inflating: ESC50/ESC-50-master/audio/2-75726-A-6.wav
#   inflating: ESC50/ESC-50-master/audio/2-76408-A-22.wav
#   inflating: ESC50/ESC-50-master/audio/2-76408-B-22.wav
#   inflating: ESC50/ESC-50-master/audio/2-76408-C-22.wav
#   inflating: ESC50/ESC-50-master/audio/2-76408-D-22.wav
#   inflating: ESC50/ESC-50-master/audio/2-76868-A-6.wav
#   inflating: ESC50/ESC-50-master/audio/2-77346-A-46.wav
#   inflating: ESC50/ESC-50-master/audio/2-77347-A-46.wav
#   inflating: ESC50/ESC-50-master/audio/2-77945-A-41.wav
#   inflating: ESC50/ESC-50-master/audio/2-77945-B-41.wav
#   inflating: ESC50/ESC-50-master/audio/2-78381-A-46.wav
#   inflating: ESC50/ESC-50-master/audio/2-78562-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/2-78562-B-37.wav
#   inflating: ESC50/ESC-50-master/audio/2-78651-A-44.wav
#   inflating: ESC50/ESC-50-master/audio/2-78781-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/2-78799-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/2-79769-A-26.wav
#   inflating: ESC50/ESC-50-master/audio/2-79775-A-26.wav
#   inflating: ESC50/ESC-50-master/audio/2-80313-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/2-80482-A-20.wav
#   inflating: ESC50/ESC-50-master/audio/2-80844-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/2-81112-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/2-81190-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/2-81270-A-1.wav
#   inflating: ESC50/ESC-50-master/audio/2-81731-A-10.wav
#   inflating: ESC50/ESC-50-master/audio/2-81970-A-7.wav
#   inflating: ESC50/ESC-50-master/audio/2-81970-B-7.wav
#   inflating: ESC50/ESC-50-master/audio/2-81970-C-7.wav
#   inflating: ESC50/ESC-50-master/audio/2-82071-A-27.wav
#   inflating: ESC50/ESC-50-master/audio/2-82077-A-7.wav
#   inflating: ESC50/ESC-50-master/audio/2-82274-A-5.wav
#   inflating: ESC50/ESC-50-master/audio/2-82274-B-5.wav
#   inflating: ESC50/ESC-50-master/audio/2-82367-A-10.wav
#   inflating: ESC50/ESC-50-master/audio/2-82455-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/2-82538-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/2-83270-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/2-83536-A-27.wav
#   inflating: ESC50/ESC-50-master/audio/2-83667-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/2-83688-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/2-83934-A-5.wav
#   inflating: ESC50/ESC-50-master/audio/2-83934-B-5.wav
#   inflating: ESC50/ESC-50-master/audio/2-84693-A-49.wav
#   inflating: ESC50/ESC-50-master/audio/2-84943-A-18.wav
#   inflating: ESC50/ESC-50-master/audio/2-84965-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/2-85139-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/2-85292-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/2-85434-A-27.wav
#   inflating: ESC50/ESC-50-master/audio/2-85471-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/2-85945-A-18.wav
#   inflating: ESC50/ESC-50-master/audio/2-86160-A-27.wav
#   inflating: ESC50/ESC-50-master/audio/2-87282-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/2-87412-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/2-87780-A-33.wav
#   inflating: ESC50/ESC-50-master/audio/2-87781-A-10.wav
#   inflating: ESC50/ESC-50-master/audio/2-87794-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/2-87795-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/2-87799-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/2-88724-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/2-89516-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/2-91912-A-33.wav
#   inflating: ESC50/ESC-50-master/audio/2-91912-B-33.wav
#   inflating: ESC50/ESC-50-master/audio/2-92627-A-27.wav
#   inflating: ESC50/ESC-50-master/audio/2-92978-A-29.wav
#   inflating: ESC50/ESC-50-master/audio/2-93030-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/2-94230-A-27.wav
#   inflating: ESC50/ESC-50-master/audio/2-94807-A-29.wav
#   inflating: ESC50/ESC-50-master/audio/2-95035-A-1.wav
#   inflating: ESC50/ESC-50-master/audio/2-95258-A-1.wav
#   inflating: ESC50/ESC-50-master/audio/2-95258-B-1.wav
#   inflating: ESC50/ESC-50-master/audio/2-95567-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/2-96033-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/2-96063-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/2-96460-A-1.wav
#   inflating: ESC50/ESC-50-master/audio/2-96654-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/2-96904-A-27.wav
#   inflating: ESC50/ESC-50-master/audio/2-98392-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/2-98676-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/2-98866-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/2-99795-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/2-99796-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/2-99955-A-7.wav
# ...
#   inflating: ESC50/ESC-50-master/audio/5-198600-A-45.wav
#   inflating: ESC50/ESC-50-master/audio/5-198891-A-8.wav
#   inflating: ESC50/ESC-50-master/audio/5-198891-B-8.wav
#   inflating: ESC50/ESC-50-master/audio/5-198891-C-8.wav
#   inflating: ESC50/ESC-50-master/audio/5-198891-D-8.wav
#   inflating: ESC50/ESC-50-master/audio/5-199284-A-45.wav
#   inflating: ESC50/ESC-50-master/audio/5-199284-B-45.wav
#   inflating: ESC50/ESC-50-master/audio/5-200329-A-8.wav
#   inflating: ESC50/ESC-50-master/audio/5-200329-B-8.wav
#   inflating: ESC50/ESC-50-master/audio/5-200329-C-8.wav
#   inflating: ESC50/ESC-50-master/audio/5-200334-A-1.wav
#   inflating: ESC50/ESC-50-master/audio/5-200334-B-1.wav
#   inflating: ESC50/ESC-50-master/audio/5-200339-A-1.wav
#   inflating: ESC50/ESC-50-master/audio/5-200461-A-11.wav
#   inflating: ESC50/ESC-50-master/audio/5-200461-B-11.wav
#   inflating: ESC50/ESC-50-master/audio/5-201170-A-46.wav
#   inflating: ESC50/ESC-50-master/audio/5-201172-A-46.wav
#   inflating: ESC50/ESC-50-master/audio/5-201194-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/5-201274-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/5-201664-A-18.wav
#   inflating: ESC50/ESC-50-master/audio/5-202020-A-18.wav
#   inflating: ESC50/ESC-50-master/audio/5-202220-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/5-202540-A-18.wav
#   inflating: ESC50/ESC-50-master/audio/5-202795-A-3.wav
#   inflating: ESC50/ESC-50-master/audio/5-202898-A-10.wav
#   inflating: ESC50/ESC-50-master/audio/5-203128-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/5-203128-B-0.wav
#   inflating: ESC50/ESC-50-master/audio/5-203739-A-10.wav
#   inflating: ESC50/ESC-50-master/audio/5-204114-A-29.wav
#   inflating: ESC50/ESC-50-master/audio/5-204352-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/5-204352-B-13.wav
#   inflating: ESC50/ESC-50-master/audio/5-204604-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/5-204741-A-46.wav
#   inflating: ESC50/ESC-50-master/audio/5-205090-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/5-205589-A-17.wav
#   inflating: ESC50/ESC-50-master/audio/5-205589-B-17.wav
#   inflating: ESC50/ESC-50-master/audio/5-205898-A-40.wav
#   inflating: ESC50/ESC-50-master/audio/5-207681-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/5-207781-A-17.wav
#   inflating: ESC50/ESC-50-master/audio/5-207811-A-35.wav
#   inflating: ESC50/ESC-50-master/audio/5-207811-B-35.wav
#   inflating: ESC50/ESC-50-master/audio/5-207836-A-29.wav
#   inflating: ESC50/ESC-50-master/audio/5-207836-B-29.wav
#   inflating: ESC50/ESC-50-master/audio/5-207836-C-29.wav
#   inflating: ESC50/ESC-50-master/audio/5-207836-D-29.wav
#   inflating: ESC50/ESC-50-master/audio/5-208030-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/5-208624-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/5-208761-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/5-208810-A-11.wav
#   inflating: ESC50/ESC-50-master/audio/5-208810-B-11.wav
#   inflating: ESC50/ESC-50-master/audio/5-209698-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/5-209719-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/5-209833-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/5-209989-A-22.wav
#   inflating: ESC50/ESC-50-master/audio/5-209992-A-44.wav
#   inflating: ESC50/ESC-50-master/audio/5-209992-B-44.wav
#   inflating: ESC50/ESC-50-master/audio/5-210540-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/5-210571-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/5-210612-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/5-211197-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/5-211408-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/5-212050-A-27.wav
#   inflating: ESC50/ESC-50-master/audio/5-212054-A-36.wav
#   inflating: ESC50/ESC-50-master/audio/5-212059-A-36.wav
#   inflating: ESC50/ESC-50-master/audio/5-212181-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/5-212454-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/5-212730-A-17.wav
#   inflating: ESC50/ESC-50-master/audio/5-212734-A-17.wav
#   inflating: ESC50/ESC-50-master/audio/5-212736-A-17.wav
#   inflating: ESC50/ESC-50-master/audio/5-213077-A-11.wav
#   inflating: ESC50/ESC-50-master/audio/5-213293-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/5-213802-A-12.wav
#   inflating: ESC50/ESC-50-master/audio/5-213836-A-9.wav
#   inflating: ESC50/ESC-50-master/audio/5-213836-B-9.wav
#   inflating: ESC50/ESC-50-master/audio/5-213836-C-9.wav
#   inflating: ESC50/ESC-50-master/audio/5-213836-D-9.wav
#   inflating: ESC50/ESC-50-master/audio/5-213855-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/5-214362-A-17.wav
#   inflating: ESC50/ESC-50-master/audio/5-214759-A-5.wav
#   inflating: ESC50/ESC-50-master/audio/5-214759-B-5.wav
#   inflating: ESC50/ESC-50-master/audio/5-214869-A-9.wav
#   inflating: ESC50/ESC-50-master/audio/5-215005-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/5-215172-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/5-215179-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/5-215445-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/5-215447-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/5-215449-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/5-215634-A-17.wav
#   inflating: ESC50/ESC-50-master/audio/5-215658-A-12.wav
#   inflating: ESC50/ESC-50-master/audio/5-215658-B-12.wav
#   inflating: ESC50/ESC-50-master/audio/5-216131-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/5-216213-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/5-216214-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/5-216216-A-13.wav
#   inflating: ESC50/ESC-50-master/audio/5-216368-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/5-216370-A-41.wav
#   inflating: ESC50/ESC-50-master/audio/5-216370-B-41.wav
#   inflating: ESC50/ESC-50-master/audio/5-217158-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/5-217186-A-16.wav
#   inflating: ESC50/ESC-50-master/audio/5-217186-B-16.wav
#   inflating: ESC50/ESC-50-master/audio/5-217186-C-16.wav
#   inflating: ESC50/ESC-50-master/audio/5-218196-A-27.wav
#   inflating: ESC50/ESC-50-master/audio/5-218196-B-27.wav
#   inflating: ESC50/ESC-50-master/audio/5-218494-A-22.wav
#   inflating: ESC50/ESC-50-master/audio/5-218980-A-30.wav
#   inflating: ESC50/ESC-50-master/audio/5-218981-A-30.wav
#   inflating: ESC50/ESC-50-master/audio/5-219044-A-46.wav
#   inflating: ESC50/ESC-50-master/audio/5-219242-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/5-219242-B-37.wav
#   inflating: ESC50/ESC-50-master/audio/5-219318-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/5-219342-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/5-219379-A-11.wav
#   inflating: ESC50/ESC-50-master/audio/5-219379-B-11.wav
#   inflating: ESC50/ESC-50-master/audio/5-219379-C-11.wav
#   inflating: ESC50/ESC-50-master/audio/5-220026-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/5-220027-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/5-220939-A-27.wav
#   inflating: ESC50/ESC-50-master/audio/5-220955-A-40.wav
#   inflating: ESC50/ESC-50-master/audio/5-221518-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/5-221528-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/5-221529-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/5-221567-A-22.wav
#   inflating: ESC50/ESC-50-master/audio/5-221568-A-22.wav
#   inflating: ESC50/ESC-50-master/audio/5-221593-A-21.wav
#   inflating: ESC50/ESC-50-master/audio/5-221878-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/5-221950-A-22.wav
#   inflating: ESC50/ESC-50-master/audio/5-222041-A-9.wav
#   inflating: ESC50/ESC-50-master/audio/5-222524-A-41.wav
#   inflating: ESC50/ESC-50-master/audio/5-222894-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/5-223099-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/5-223099-B-32.wav
#   inflating: ESC50/ESC-50-master/audio/5-223103-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/5-223176-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/5-223317-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/5-223810-A-35.wav
#   inflating: ESC50/ESC-50-master/audio/5-231551-A-36.wav
#   inflating: ESC50/ESC-50-master/audio/5-231762-A-0.wav
#   inflating: ESC50/ESC-50-master/audio/5-232272-A-44.wav
#   inflating: ESC50/ESC-50-master/audio/5-232802-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/5-232816-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/5-233019-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/5-233160-A-1.wav
#   inflating: ESC50/ESC-50-master/audio/5-233260-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/5-233312-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/5-233605-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/5-233607-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/5-233645-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/5-233787-A-7.wav
#   inflating: ESC50/ESC-50-master/audio/5-234145-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/5-234247-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/5-234263-A-25.wav
#   inflating: ESC50/ESC-50-master/audio/5-234335-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/5-234855-A-25.wav
#   inflating: ESC50/ESC-50-master/audio/5-234879-A-1.wav
#   inflating: ESC50/ESC-50-master/audio/5-234879-B-1.wav
#   inflating: ESC50/ESC-50-master/audio/5-234923-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/5-235507-A-44.wav
#   inflating: ESC50/ESC-50-master/audio/5-235593-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/5-235644-A-30.wav
#   inflating: ESC50/ESC-50-master/audio/5-235671-A-38.wav
#   inflating: ESC50/ESC-50-master/audio/5-235874-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/5-235893-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/5-235956-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/5-236288-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/5-236299-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/5-237315-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/5-237499-A-4.wav
#   inflating: ESC50/ESC-50-master/audio/5-237795-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/5-238021-A-35.wav
#   inflating: ESC50/ESC-50-master/audio/5-238492-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/5-238926-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/5-238938-A-27.wav
#   inflating: ESC50/ESC-50-master/audio/5-240671-A-44.wav
#   inflating: ESC50/ESC-50-master/audio/5-241846-A-15.wav
#   inflating: ESC50/ESC-50-master/audio/5-242490-A-14.wav
#   inflating: ESC50/ESC-50-master/audio/5-242491-A-14.wav
#   inflating: ESC50/ESC-50-master/audio/5-242492-A-3.wav
#   inflating: ESC50/ESC-50-master/audio/5-242711-A-9.wav
#   inflating: ESC50/ESC-50-master/audio/5-242932-A-26.wav
#   inflating: ESC50/ESC-50-master/audio/5-242932-B-26.wav
#   inflating: ESC50/ESC-50-master/audio/5-243025-A-25.wav
#   inflating: ESC50/ESC-50-master/audio/5-243036-A-29.wav
#   inflating: ESC50/ESC-50-master/audio/5-243448-A-14.wav
#   inflating: ESC50/ESC-50-master/audio/5-243449-A-14.wav
#   inflating: ESC50/ESC-50-master/audio/5-243450-A-14.wav
#   inflating: ESC50/ESC-50-master/audio/5-243459-A-14.wav
#   inflating: ESC50/ESC-50-master/audio/5-243459-B-14.wav
#   inflating: ESC50/ESC-50-master/audio/5-243635-A-29.wav
#   inflating: ESC50/ESC-50-master/audio/5-243773-A-44.wav
#   inflating: ESC50/ESC-50-master/audio/5-243773-B-44.wav
#   inflating: ESC50/ESC-50-master/audio/5-243783-A-44.wav
#   inflating: ESC50/ESC-50-master/audio/5-244178-A-32.wav
#   inflating: ESC50/ESC-50-master/audio/5-244310-A-25.wav
#   inflating: ESC50/ESC-50-master/audio/5-244315-A-6.wav
#   inflating: ESC50/ESC-50-master/audio/5-244315-B-6.wav
#   inflating: ESC50/ESC-50-master/audio/5-244315-C-6.wav
#   inflating: ESC50/ESC-50-master/audio/5-244327-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/5-244459-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/5-244526-A-26.wav
#   inflating: ESC50/ESC-50-master/audio/5-244651-A-31.wav
#   inflating: ESC50/ESC-50-master/audio/5-244933-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/5-245040-A-35.wav
#   inflating: ESC50/ESC-50-master/audio/5-248341-A-6.wav
#   inflating: ESC50/ESC-50-master/audio/5-248341-B-6.wav
#   inflating: ESC50/ESC-50-master/audio/5-248341-C-6.wav
#   inflating: ESC50/ESC-50-master/audio/5-249748-A-28.wav
#   inflating: ESC50/ESC-50-master/audio/5-249937-A-22.wav
#   inflating: ESC50/ESC-50-master/audio/5-250026-A-30.wav
#   inflating: ESC50/ESC-50-master/audio/5-250026-B-30.wav
#   inflating: ESC50/ESC-50-master/audio/5-250258-A-49.wav
#   inflating: ESC50/ESC-50-master/audio/5-250629-A-37.wav
#   inflating: ESC50/ESC-50-master/audio/5-250753-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/5-251426-A-30.wav
#   inflating: ESC50/ESC-50-master/audio/5-251426-B-30.wav
#   inflating: ESC50/ESC-50-master/audio/5-251489-A-24.wav
#   inflating: ESC50/ESC-50-master/audio/5-251957-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/5-251962-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/5-251963-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/5-251971-A-47.wav
#   inflating: ESC50/ESC-50-master/audio/5-252248-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/5-253085-A-3.wav
#   inflating: ESC50/ESC-50-master/audio/5-253085-B-3.wav
#   inflating: ESC50/ESC-50-master/audio/5-253094-A-49.wav
#   inflating: ESC50/ESC-50-master/audio/5-253094-B-49.wav
#   inflating: ESC50/ESC-50-master/audio/5-253094-C-49.wav
#   inflating: ESC50/ESC-50-master/audio/5-253094-D-49.wav
#   inflating: ESC50/ESC-50-master/audio/5-253101-A-49.wav
#   inflating: ESC50/ESC-50-master/audio/5-253101-B-49.wav
#   inflating: ESC50/ESC-50-master/audio/5-253101-C-49.wav
#   inflating: ESC50/ESC-50-master/audio/5-253534-A-26.wav
#   inflating: ESC50/ESC-50-master/audio/5-254160-A-22.wav
#   inflating: ESC50/ESC-50-master/audio/5-254832-A-15.wav
#   inflating: ESC50/ESC-50-master/audio/5-254832-B-15.wav
#   inflating: ESC50/ESC-50-master/audio/5-256452-A-5.wav
#   inflating: ESC50/ESC-50-master/audio/5-256512-A-30.wav
#   inflating: ESC50/ESC-50-master/audio/5-257349-A-15.wav
#   inflating: ESC50/ESC-50-master/audio/5-257642-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/5-257839-A-14.wav
#   inflating: ESC50/ESC-50-master/audio/5-259169-A-5.wav
#   inflating: ESC50/ESC-50-master/audio/5-259180-A-15.wav
#   inflating: ESC50/ESC-50-master/audio/5-259514-A-26.wav
#   inflating: ESC50/ESC-50-master/audio/5-259640-A-29.wav
#   inflating: ESC50/ESC-50-master/audio/5-260011-A-34.wav
#   inflating: ESC50/ESC-50-master/audio/5-260164-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/5-260432-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/5-260433-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/5-260434-A-39.wav
#   inflating: ESC50/ESC-50-master/audio/5-260875-A-35.wav
#   inflating: ESC50/ESC-50-master/audio/5-261325-A-9.wav
#   inflating: ESC50/ESC-50-master/audio/5-261433-A-15.wav
#   inflating: ESC50/ESC-50-master/audio/5-261439-A-15.wav
#   inflating: ESC50/ESC-50-master/audio/5-261464-A-23.wav
#   inflating: ESC50/ESC-50-master/audio/5-262641-A-15.wav
#   inflating: ESC50/ESC-50-master/audio/5-262957-A-22.wav
#   inflating: ESC50/ESC-50-master/audio/5-263490-A-25.wav
#   inflating: ESC50/ESC-50-master/audio/5-263491-A-25.wav
#   inflating: ESC50/ESC-50-master/audio/5-263501-A-25.wav
#   inflating: ESC50/ESC-50-master/audio/5-263775-A-26.wav
#   inflating: ESC50/ESC-50-master/audio/5-263775-B-26.wav
#   inflating: ESC50/ESC-50-master/audio/5-263831-A-6.wav
#   inflating: ESC50/ESC-50-master/audio/5-263831-B-6.wav
#   inflating: ESC50/ESC-50-master/audio/5-263902-A-36.wav
#   inflating: ESC50/ESC-50-master/audio/5-51149-A-25.wav
#   inflating: ESC50/ESC-50-master/audio/5-61635-A-8.wav
#   inflating: ESC50/ESC-50-master/audio/5-9032-A-0.wav
#   inflating: ESC50/ESC-50-master/esc50.gif
#    creating: ESC50/ESC-50-master/meta/
#   inflating: ESC50/ESC-50-master/meta/esc50-human.xlsx
#   inflating: ESC50/ESC-50-master/meta/esc50.csv
#  extracting: ESC50/ESC-50-master/pytest.ini
#   inflating: ESC50/ESC-50-master/requirements.txt
#    creating: ESC50/ESC-50-master/tests/
#   inflating: ESC50/ESC-50-master/tests/test_dataset.py

# %%
#Download GTZAN
import kagglehub

path = kagglehub.dataset_download("andradaolteanu/gtzan-dataset-music-genre-classification")
print("Dataset downloaded to:", path)
# Out:
# Using Colab cache for faster access to the 'gtzan-dataset-music-genre-classification' dataset.
# ✅ Dataset downloaded to: /kaggle/input/gtzan-dataset-music-genre-classification

# %%
# This code loads an audio file, converts it into YAMNet’s required log-mel format, runs the frozen YAMNet model, and returns a final 1024-dimensional embedding for that sound clip.

import torch, torchaudio, soundfile as sf
from torch_vggish_yamnet import yamnet
from torch_vggish_yamnet.input_proc import WaveformToInput

device = "cuda" if torch.cuda.is_available() else "cpu"

# Load pretrained YAMNet and the waveform→input converter
yamnet_model = yamnet.yamnet(pretrained=True).to(device).eval()
yamnet_converter = WaveformToInput()

@torch.no_grad()
def wav_to_yamnet_embedding(wave: torch.Tensor, sr: int):
    """
    wave: torch.Tensor of shape (channels, samples) or (samples,)
    sr: sampling rate
    returns: np.ndarray of shape (1024,) – frame-averaged YAMNet embedding
    """
    # Ensure shape (1, samples)
    if wave.ndim == 1:
        wave = wave.unsqueeze(0)
    # Resample to 16 kHz mono (YAMNet expects 16k)
    if sr != 16000:
        wave = torchaudio.functional.resample(wave, sr, 16000)
        sr = 16000
    wave = wave.mean(0, keepdim=True)  # mono

    x = yamnet_converter(wave.float(), sr).to(device)  # frames × features
    emb, _ = yamnet_model(x)                           # (frames, 1024)
    emb = emb.mean(dim=0).cpu().numpy()                # -> (1024,)
    # Ensure it's a 1D array (1024,) not (1024, 1, 1)
    emb = emb.flatten() if emb.ndim > 1 else emb
    return emb

def safe_load(fp):
    """Try torchaudio first, fallback to soundfile; always return (wave, sr)."""
    try:
        wave, sr = torchaudio.load(fp)
        return wave, sr
    except Exception:
        data, sr = sf.read(fp, dtype="float32")  # (samples,) or (samples, channels)
        if data.ndim == 1:
            data = data[:, None]                 # -> (samples, 1)
        wave = torch.from_numpy(data.T)          # -> (channels, samples)
        return wave, sr
# Out:
# Downloading: "https://github.com/w-hc/torch_audioset/releases/download/v0.1/yamnet.pth" to /root/.cache/torch/hub/checkpoints/yamnet.pth
# 100%|██████████| 14.4M/14.4M [00:00<00:00, 184MB/s]

# %%
# This code converts all ESC-50 audio clips into YAMNet’s 1024-dimensional
# embeddings and builds the dataset that will be used for zero-shot, few-shot,
# and full classification experiments.

import os
import numpy as np
import pandas as pd
from tqdm import tqdm

# 1) Paths to ESC-50 (as you already used when downloading/unzipping)
esc_root  = "ESC50/ESC-50-master"
esc_csv   = os.path.join(esc_root, "meta/esc50.csv")
esc_audio = os.path.join(esc_root, "audio")

# 2) Load metadata (filenames + categories)
esc_meta = pd.read_csv(esc_csv)

# 3) Prepare containers
X, y = [], []

# Map category name -> numeric id (0..49)
label_to_id = {lbl: i for i, lbl in enumerate(sorted(esc_meta["category"].unique()))}

# 4) Loop over all ESC-50 audio files and extract a 1024-dim embedding
for row in tqdm(esc_meta.itertuples(index=False), total=len(esc_meta)):
    wav_path = os.path.join(esc_audio, row.filename)
    try:
        # use your helper functions from the first cell
        wave, sr = safe_load(wav_path)
        emb = wav_to_yamnet_embedding(wave, sr)   # shape (1024,)
        X.append(emb)
        y.append(label_to_id[row.category])       # integer label
    except Exception as e:
        print("Failed:", wav_path, "->", e)

# 5) Stack into arrays
X = np.stack(X).astype("float32")   # shape (N, 1024)
y = np.array(y, dtype=np.int64)     # shape (N,)

print("ESC-50 embeddings shape:", X.shape)
print("ESC-50 labels shape:", y.shape)

# 6) (Optional) Save to disk for later use
np.savez_compressed("esc50_yamnet.npz",
                    X=X,
                    y=y,
                    labels=np.array(sorted(label_to_id, key=label_to_id.get)))
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# 100%|██████████| 2000/2000 [00:41<00:00, 48.72it/s]
# ESC-50 embeddings shape: (2000, 1024)
# ESC-50 labels shape: (2000,)

# %%
# This cell converts all GTZAN audio clips into 1024-D YAMNet embeddings

import os
import numpy as np
from tqdm import tqdm

# 1) Root folder to the GTZAN dataset
# If you used kagglehub.dataset_download, you probably have something like:
# path = kagglehub.dataset_download("andradaolteanu/gtzan-dataset-music-genre-classification")
# If not, set this manually:
# path = "/kaggle/input/gtzan-dataset-music-genre-classification"

gtzan_root = os.path.join(path, "Data", "genres_original")
print("Using GTZAN root:", gtzan_root)
assert os.path.isdir(gtzan_root)

# 2) Get genre subfolders
genres = sorted(
    d for d in os.listdir(gtzan_root)
    if os.path.isdir(os.path.join(gtzan_root, d))
)
print("Detected genres:", genres)

# 3) Prepare containers
X, y = [], []
label_to_id = {g: i for i, g in enumerate(genres)}
print("Label→id mapping:", label_to_id)

# 4) Loop over all files and extract one 1024-D embedding per clip
failed_files = []
for genre in genres:
    genre_id = label_to_id[genre]
    folder = os.path.join(gtzan_root, genre)
    wav_files = sorted(
        f for f in os.listdir(folder)
        if f.lower().endswith(".wav")
    )

    for fn in tqdm(wav_files, desc=f"Processing {genre}", leave=False):
        wav_path = os.path.join(folder, fn)
        try:
            wave, sr = safe_load(wav_path)
            emb = wav_to_yamnet_embedding(wave, sr)  # (1024,)
            X.append(emb)
            y.append(genre_id)
        except Exception as e:
            failed_files.append((wav_path, str(e)))
            print(f"Failed: {wav_path} -> {e}")

# Report summary of failed files
if failed_files:
    print(f"\n Total failed files: {len(failed_files)}")
    print("Failed files by genre:")
    for path, error in failed_files:
        genre_name = path.split('/')[-2]  # Extract genre from path
        print(f"  {genre_name}: {os.path.basename(path)}")
else:
    print("\n All files processed successfully!")

# 5) Stack into arrays
X = np.stack(X).astype("float32")  # shape (N, 1024)
y = np.array(y, dtype=np.int64)    # shape (N,)

print("GTZAN embeddings shape:", X.shape)
print("GTZAN labels shape:", y.shape)

# 6) Save to disk for later (for your linear SVM, NC, etc.)
np.savez_compressed(
    "gtzan_yamnet.npz",
    X=X,
    y=y,
    labels=np.array(genres)
)
print("Saved gtzan_yamnet.npz")
# Out:
# Using GTZAN root: /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original
# Detected genres: ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
# Label→id mapping: {'blues': 0, 'classical': 1, 'country': 2, 'disco': 3, 'hiphop': 4, 'jazz': 5, 'metal': 6, 'pop': 7, 'reggae': 8, 'rock': 9}
# Processing jazz:  59%|█████▉    | 59/100 [00:02<00:02, 19.16it/s]
# Failed: /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/jazz/jazz.00054.wav -> Error opening '/kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/jazz/jazz.00054.wav': Format not recognised.
# GTZAN embeddings shape: (999, 1024)
# GTZAN labels shape: (999,)
# Saved gtzan_yamnet.npz

# %% [markdown]
# ## Loading Embeddings

# %%
import numpy as np
import pandas as pd
import os

def flatten_embeddings(X):
    """
    Converts embeddings of shape (N, *, 1024) → (N, 1024)
    by reshaping/flattening extra dimensions.
    """
    X = np.asarray(X)

    # If already correct shape, return as is
    if X.ndim == 2 and X.shape[1] == 1024:
        return X

    # Find the dimension that is 1024
    embed_dim = None
    for i, s in enumerate(X.shape):
        if s == 1024:
            embed_dim = i
            break

    if embed_dim is None:
        raise ValueError(f"Could not find dimension of size 1024 in shape {X.shape}")

    # Move 1024 to last axis
    X = np.moveaxis(X, embed_dim, -1)

    # Reshape to (N, 1024) - flatten all dimensions except first and last
    if X.ndim > 2:
        # Reshape: keep first dim, flatten middle dims, keep last dim (1024)
        new_shape = (X.shape[0], -1, X.shape[-1])
        X = X.reshape(new_shape)
        # If still more than 2 dims, squeeze middle dims
        while X.ndim > 2:
            X = X.squeeze(axis=1) if X.shape[1] == 1 else X.reshape(X.shape[0], -1)

    return X

# Load embeddings
esc = np.load("esc50_yamnet.npz")
X_esc, y_esc = esc["X"], esc["y"]
esc_labels = esc["labels"] if "labels" in esc.keys() else None

gtz = np.load("gtzan_yamnet.npz")
X_gtzan, y_gtzan = gtz["X"], gtz["y"]
gtzan_labels = gtz["labels"] if "labels" in gtz.keys() else None

print("Original ESC-50 shape:", X_esc.shape, y_esc.shape)
print("Original GTZAN shape:", X_gtzan.shape, y_gtzan.shape)

# Load ESC-50 metadata to get category names
esc_root = "ESC50/ESC-50-master"
esc_csv = os.path.join(esc_root, "meta/esc50.csv")
esc_meta = pd.read_csv(esc_csv)

# Get all unique categories from metadata
all_categories = sorted(esc_meta["category"].unique())
print(f"\nTotal ESC-50 categories: {len(all_categories)}")
print(f"ESC-50 categories: {all_categories[:10]}... (showing first 10)")

# Flatten embeddings if needed
X_esc_flat = flatten_embeddings(X_esc)
X_gtzan_flat = flatten_embeddings(X_gtzan)

print(f"\nFlattened ESC-50 shape: {X_esc_flat.shape}")
print(f"Flattened GTZAN shape: {X_gtzan_flat.shape}")
print(f"ESC-50 number of classes: {len(np.unique(y_esc))}")
print(f"GTZAN number of classes: {len(np.unique(y_gtzan))}")
print(f"Samples per ESC-50 class: {np.bincount(y_esc)}")

# Verify shapes are correct
assert X_esc_flat.shape == (len(y_esc), 1024), f"ESC-50 shape mismatch: {X_esc_flat.shape}"
assert X_gtzan_flat.shape == (len(y_gtzan), 1024), f"GTZAN shape mismatch: {X_gtzan_flat.shape}"
print("\n✅ Embedding shapes verified!")
# Out:
# Original ESC-50 shape: (2000, 1024) (2000,)
# Original GTZAN shape: (999, 1024) (999,)
#
# Total ESC-50 categories: 50
# ESC-50 categories: ['airplane', 'breathing', 'brushing_teeth', 'can_opening', 'car_horn', 'cat', 'chainsaw', 'chirping_birds', 'church_bells', 'clapping']... (showing first 10)
#
# Flattened ESC-50 shape: (2000, 1024)
# Flattened GTZAN shape: (999, 1024)
# ESC-50 number of classes: 50
# GTZAN number of classes: 10
# Samples per ESC-50 class: [40 40 40 40 40 40 40 40 40 40 40 40 40 40 40 40 40 40 40 40 40 40 40 40
#  40 40 40 40 40 40 40 40 40 40 40 40 40 40 40 40 40 40 40 40 40 40 40 40
#  40 40]
#
# ✅ Embedding shapes verified!

# %%
# Note: flatten_embeddings() is already defined in the previous cell
# This cell is kept for backward compatibility but the function is defined above
# The embeddings are already flattened in cell 8

# %% [markdown]
# ## Zero-Shot Experiments

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

def zero_shot_baseline(clf, X_src, y_src, X_tgt, y_tgt, return_all_metrics=False):
    """
    Zero-shot transfer: train on source (GTZAN), test on target (ESC-50 animals)
    Returns accuracy, macro-F1, and optionally confusion matrix
    """
    scaler = StandardScaler()
    X_src_s = scaler.fit_transform(X_src)
    X_tgt_s = scaler.transform(X_tgt)

    clf.fit(X_src_s, y_src)
    preds = clf.predict(X_tgt_s)

    acc = accuracy_score(y_tgt, preds)
    macro_f1 = f1_score(y_tgt, preds, average='macro', zero_division=0)

    if return_all_metrics:
        cm = confusion_matrix(y_tgt, preds)
        return acc, macro_f1, cm, preds
    return acc, macro_f1

# %% [markdown]
# ### Random Forest

# %%
# Note: zero_shot_baseline() is already defined in Cell 11 above
# This cell removed to avoid duplication

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=500, n_jobs=-1, random_state=42)
acc_rf, f1_rf = zero_shot_baseline(rf, X_gtzan_flat, y_gtzan, X_esc_flat, y_esc)
print(f"Zero-shot RF - Accuracy: {acc_rf:.4f}, Macro-F1: {f1_rf:.4f}")
# Out:
# Zero-shot RF - Accuracy: 0.0245, Macro-F1: 0.0069

# %% [markdown]
# ### Log Regression (on CPU)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(max_iter=2000, n_jobs=-1, C=1.0)
acc_lr, f1_lr = zero_shot_baseline(lr, X_gtzan_flat, y_gtzan, X_esc_flat, y_esc)
print(f"Zero-shot LogReg - Accuracy: {acc_lr:.4f}, Macro-F1: {f1_lr:.4f}")
# Out:
# Zero-shot LogReg - Accuracy: 0.0400, Macro-F1: 0.0097

# %% [markdown]
# ### Ridge Classifier

# %%
from sklearn.linear_model import RidgeClassifier

ridge = RidgeClassifier(alpha=1.0)
acc_ridge, f1_ridge = zero_shot_baseline(ridge, X_gtzan_flat, y_gtzan, X_esc_flat, y_esc)
print(f"Zero-shot Ridge - Accuracy: {acc_ridge:.4f}, Macro-F1: {f1_ridge:.4f}")
# Out:
# Zero-shot Ridge - Accuracy: 0.0120, Macro-F1: 0.0040

# %% [markdown]
# ## Few Shot Experiments

# %%
import numpy as np
from collections import defaultdict

def sample_few_shot(X, y, k, seed=0):
    rng = np.random.default_rng(seed)
    classes = np.unique(y)

    idx_fs, idx_rest = [], []
    for c in classes:
        c_idx = np.where(y == c)[0]
        rng.shuffle(c_idx)
        k = min(k, len(c_idx))
        idx_fs.extend(c_idx[:k])
        idx_rest.extend(c_idx[k:])

    return (
        X[idx_fs], y[idx_fs],
        X[idx_rest], y[idx_rest]
    )

# %%
def few_shot_experiment(clf, X_src, y_src, X_tgt, y_tgt, k_list=[1,5,10,20]):
    """
    Few-shot transfer: train on GTZAN + k samples per class from ESC-50, test on remaining ESC-50
    Returns dict with accuracy and macro-F1 for each k
    """
    results = {}
    for k in k_list:
        print(f"\nRunning few-shot (k={k})")

        X_fs, y_fs, X_rest, y_rest = sample_few_shot(X_tgt, y_tgt, k)

        # combine GTZAN + few ESC-50
        X_train = np.concatenate([X_src, X_fs])
        y_train = np.concatenate([y_src, y_fs])

        scaler = StandardScaler()
        X_train_s = scaler.fit_transform(X_train)
        X_test_s = scaler.transform(X_rest)

        clf.fit(X_train_s, y_train)
        preds = clf.predict(X_test_s)

        acc = accuracy_score(y_rest, preds)
        macro_f1 = f1_score(y_rest, preds, average='macro', zero_division=0)

        results[k] = {'accuracy': acc, 'macro_f1': macro_f1}
        print(f"k={k}: Accuracy={acc:.4f}, Macro-F1={macro_f1:.4f}")

    return results

# %%
#RF
rf = RandomForestClassifier(n_estimators=500, n_jobs=-1, random_state=42)
rf_few = few_shot_experiment(rf, X_gtzan_flat, y_gtzan, X_esc_flat, y_esc)
# Out:
# Running few-shot (k=1)
# k=1: Accuracy=0.3533, Macro-F1=0.3373
#
# Running few-shot (k=5)
# k=5: Accuracy=0.6623, Macro-F1=0.6533
#
# Running few-shot (k=10)
# k=10: Accuracy=0.7793, Macro-F1=0.7788
#
# Running few-shot (k=20)
# k=20: Accuracy=0.8130, Macro-F1=0.8105

# %%
#LR
lr = LogisticRegression(max_iter=2000, n_jobs=-1)
lr_few = few_shot_experiment(lr, X_gtzan_flat, y_gtzan, X_esc_flat, y_esc)
# Out:
# Running few-shot (k=1)
# k=1: Accuracy=0.2831, Macro-F1=0.3225
#
# Running few-shot (k=5)
# k=5: Accuracy=0.7046, Macro-F1=0.7082
#
# Running few-shot (k=10)
# k=10: Accuracy=0.7840, Macro-F1=0.7887
#
# Running few-shot (k=20)
# k=20: Accuracy=0.8270, Macro-F1=0.8294

# %%
#Ridge
ridge = RidgeClassifier(alpha=1.0)
ridge_few = few_shot_experiment(ridge, X_gtzan_flat, y_gtzan, X_esc_flat, y_esc)
# Out:
# Running few-shot (k=1)
# k=1: Accuracy=0.0749, Macro-F1=0.0791
#
# Running few-shot (k=5)
# k=5: Accuracy=0.5337, Macro-F1=0.5699
#
# Running few-shot (k=10)
# k=10: Accuracy=0.7460, Macro-F1=0.7510
#
# Running few-shot (k=20)
# k=20: Accuracy=0.8190, Macro-F1=0.8183

# %% [markdown]
# ## Full Fine-Tuning Experiment (Upper Bound)
#
# Train classifier on all ESC-50 data to establish upper-bound performance.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from sklearn.preprocessing import StandardScaler

def full_finetune_experiment(clf, X_esc, y_esc, test_size=0.2, random_state=42):
    """
    Full fine-tuning: train classifier on all ESC-50 data (train/test split)
    This establishes the upper-bound performance
    """
    # Split ESC-50 into train/test
    X_train, X_test, y_train, y_test = train_test_split(
        X_esc, y_esc, test_size=test_size, random_state=random_state, stratify=y_esc
    )
    
    # Scale features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    # Train classifier
    clf.fit(X_train_scaled, y_train)
    
    # Evaluate
    preds = clf.predict(X_test_scaled)
    acc = accuracy_score(y_test, preds)
    macro_f1 = f1_score(y_test, preds, average='macro', zero_division=0)
    cm = confusion_matrix(y_test, preds)
    
    return acc, macro_f1, cm, preds, y_test

# Run full fine-tuning experiments
print("=" * 60)
print("FULL FINE-TUNING EXPERIMENTS (Upper Bound)")
print("=" * 60)

# Random Forest
rf_full = RandomForestClassifier(n_estimators=500, n_jobs=-1, random_state=42)
acc_rf_full, f1_rf_full, cm_rf_full, preds_rf_full, y_test_rf = full_finetune_experiment(
    rf_full, X_esc_flat, y_esc
)
print(f"\nRF Full Fine-tune - Accuracy: {acc_rf_full:.4f}, Macro-F1: {f1_rf_full:.4f}")

# Logistic Regression
lr_full = LogisticRegression(max_iter=2000, n_jobs=-1, random_state=42)
acc_lr_full, f1_lr_full, cm_lr_full, preds_lr_full, y_test_lr = full_finetune_experiment(
    lr_full, X_esc_flat, y_esc
)
print(f"LR Full Fine-tune - Accuracy: {acc_lr_full:.4f}, Macro-F1: {f1_lr_full:.4f}")

# Ridge
ridge_full = RidgeClassifier(alpha=1.0, random_state=42)
acc_ridge_full, f1_ridge_full, cm_ridge_full, preds_ridge_full, y_test_ridge = full_finetune_experiment(
    ridge_full, X_esc_flat, y_esc
)
print(f"Ridge Full Fine-tune - Accuracy: {acc_ridge_full:.4f}, Macro-F1: {f1_ridge_full:.4f}")

# %%
# Note: Full fine-tuning experiments are now in Cell 26 above
# This redundant cell has been removed
# Out:
# RF Zero-shot accuracy: 0.0205
# LR Zero-shot accuracy: 0.029
# Ridge Zero-shot accuracy: 0.018

# %%
# Note: Few-shot experiments are already implemented in Cells 19-24 above
# This redundant cell has been removed

# %%
# Note: Few-shot experiments are already implemented in Cells 19-24 above
# This redundant cell has been removed
# Out:
# RF few-shot (k=1) - Accuracy: 0.3503, Macro-F1: 0.3341
# RF few-shot (k=5) - Accuracy: 0.6834, Macro-F1: 0.6709
# RF few-shot (k=10) - Accuracy: 0.7760, Macro-F1: 0.7724
# RF few-shot (k=20) - Accuracy: 0.8550, Macro-F1: 0.8531
# LR few-shot (k=1) - Accuracy: 0.3467, Macro-F1: 0.3559
# LR few-shot (k=5) - Accuracy: 0.7160, Macro-F1: 0.7139
# LR few-shot (k=10) - Accuracy: 0.7847, Macro-F1: 0.7867
# LR few-shot (k=20) - Accuracy: 0.8430, Macro-F1: 0.8437
# Ridge few-shot (k=1) - Accuracy: 0.0800, Macro-F1: 0.0704
# Ridge few-shot (k=5) - Accuracy: 0.5474, Macro-F1: 0.5739
# Ridge few-shot (k=10) - Accuracy: 0.7507, Macro-F1: 0.7539
# Ridge few-shot (k=20) - Accuracy: 0.8200, Macro-F1: 0.8193

# %% [markdown]
# ## Results Summary and Visualizations

# %%
# Note: This cell referenced the old zero_shot_transfer function which has been removed
# Zero-shot experiments are now in Cells 10-18 above
# Out:
# 0.0245

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from sklearn.preprocessing import StandardScaler

def full_finetune_experiment(clf, X_esc, y_esc, test_size=0.2, random_state=42):
    """
    Full fine-tuning: train classifier on all ESC-50 data (train/test split)
    This establishes the upper-bound performance
    """
    # Split ESC-50 into train/test
    X_train, X_test, y_train, y_test = train_test_split(
        X_esc, y_esc, test_size=test_size, random_state=random_state, stratify=y_esc
    )

    # Scale features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Train classifier
    clf.fit(X_train_scaled, y_train)

    # Evaluate
    preds = clf.predict(X_test_scaled)
    acc = accuracy_score(y_test, preds)
    macro_f1 = f1_score(y_test, preds, average='macro', zero_division=0)
    cm = confusion_matrix(y_test, preds)

    return acc, macro_f1, cm, preds, y_test

# Run full fine-tuning experiments
print("=" * 60)
print("FULL FINE-TUNING EXPERIMENTS (Upper Bound)")
print("=" * 60)

# Random Forest
rf_full = RandomForestClassifier(n_estimators=500, n_jobs=-1, random_state=42)
acc_rf_full, f1_rf_full, cm_rf_full, preds_rf_full, y_test_rf = full_finetune_experiment(
    rf_full, X_esc_flat, y_esc
)
print(f"\nRF Full Fine-tune - Accuracy: {acc_rf_full:.4f}, Macro-F1: {f1_rf_full:.4f}")

# Logistic Regression
lr_full = LogisticRegression(max_iter=2000, n_jobs=-1, random_state=42)
acc_lr_full, f1_lr_full, cm_lr_full, preds_lr_full, y_test_lr = full_finetune_experiment(
    lr_full, X_esc_flat, y_esc
)
print(f"LR Full Fine-tune - Accuracy: {acc_lr_full:.4f}, Macro-F1: {f1_lr_full:.4f}")

# Ridge
ridge_full = RidgeClassifier(alpha=1.0, random_state=42)
acc_ridge_full, f1_ridge_full, cm_ridge_full, preds_ridge_full, y_test_ridge = full_finetune_experiment(
    ridge_full, X_esc_flat, y_esc
)
print(f"Ridge Full Fine-tune - Accuracy: {acc_ridge_full:.4f}, Macro-F1: {f1_ridge_full:.4f}")
# Out:
# ============================================================
# FULL FINE-TUNING EXPERIMENTS (Upper Bound)
# ============================================================
#
# RF Full Fine-tune - Accuracy: 0.8650, Macro-F1: 0.8647
# LR Full Fine-tune - Accuracy: 0.8575, Macro-F1: 0.8564
# Ridge Full Fine-tune - Accuracy: 0.8475, Macro-F1: 0.8472

# %% [markdown]
# ## Results Summary and Visualizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Set style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# Collect zero-shot results
zero_shot_results = {
    'Random Forest': {'accuracy': acc_rf, 'macro_f1': f1_rf},
    'Logistic Regression': {'accuracy': acc_lr, 'macro_f1': f1_lr},
    'Ridge': {'accuracy': acc_ridge, 'macro_f1': f1_ridge}
}

# Collect few-shot results (for k=20 as example)
# Note: few_shot_experiment returns a dict with k as keys
few_shot_k20 = {
    'Random Forest': rf_few[20],
    'Logistic Regression': lr_few[20],
    'Ridge': ridge_few[20]
}

# Collect full fine-tuning results
full_finetune_results = {
    'Random Forest': {'accuracy': acc_rf_full, 'macro_f1': f1_rf_full},
    'Logistic Regression': {'accuracy': acc_lr_full, 'macro_f1': f1_lr_full},
    'Ridge': {'accuracy': acc_ridge_full, 'macro_f1': f1_ridge_full}
}

# Create summary table
summary_data = {
    'Classifier': [],
    'Zero-shot Accuracy': [],
    'Zero-shot Macro-F1': [],
    'Few-shot (k=20) Accuracy': [],
    'Few-shot (k=20) Macro-F1': [],
    'Full Fine-tune Accuracy': [],
    'Full Fine-tune Macro-F1': []
}

for clf_name in ['Random Forest', 'Logistic Regression', 'Ridge']:
    summary_data['Classifier'].append(clf_name)
    summary_data['Zero-shot Accuracy'].append(f"{zero_shot_results[clf_name]['accuracy']:.4f}")
    summary_data['Zero-shot Macro-F1'].append(f"{zero_shot_results[clf_name]['macro_f1']:.4f}")
    summary_data['Few-shot (k=20) Accuracy'].append(f"{few_shot_k20[clf_name]['accuracy']:.4f}")
    summary_data['Few-shot (k=20) Macro-F1'].append(f"{few_shot_k20[clf_name]['macro_f1']:.4f}")
    summary_data['Full Fine-tune Accuracy'].append(f"{full_finetune_results[clf_name]['accuracy']:.4f}")
    summary_data['Full Fine-tune Macro-F1'].append(f"{full_finetune_results[clf_name]['macro_f1']:.4f}")

summary_df = pd.DataFrame(summary_data)
print("\n" + "=" * 100)
print("RESULTS SUMMARY")
print("=" * 100)
print(summary_df.to_string(index=False))
# Out:
# ====================================================================================================
# RESULTS SUMMARY
# ====================================================================================================
#          Classifier Zero-shot Accuracy Zero-shot Macro-F1 Few-shot (k=20) Accuracy Few-shot (k=20) Macro-F1 Full Fine-tune Accuracy Full Fine-tune Macro-F1
#       Random Forest             0.0245             0.0069                   0.8550                   0.8531                  0.8650                  0.8647
# Logistic Regression             0.0400             0.0097                   0.8430                   0.8437                  0.8575                  0.8564
#               Ridge             0.0120             0.0040                   0.8200                   0.8193                  0.8475                  0.8472

# %%
# Plot 1: Performance vs k for few-shot learning
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

k_values = sorted(rf_few.keys())
classifiers = ['Random Forest', 'Logistic Regression', 'Ridge']
results_dicts = [rf_few, lr_few, ridge_few]

# Accuracy plot
for clf_name, results in zip(classifiers, results_dicts):
    accs = [results[k]['accuracy'] for k in k_values]
    axes[0].plot(k_values, accs, marker='o', label=clf_name, linewidth=2)

axes[0].set_xlabel('Number of samples per class (k)', fontsize=12)
axes[0].set_ylabel('Accuracy', fontsize=12)
axes[0].set_title('Few-Shot Learning: Accuracy vs k', fontsize=14, fontweight='bold')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Macro-F1 plot
for clf_name, results in zip(classifiers, results_dicts):
    f1s = [results[k]['macro_f1'] for k in k_values]
    axes[1].plot(k_values, f1s, marker='s', label=clf_name, linewidth=2)

axes[1].set_xlabel('Number of samples per class (k)', fontsize=12)
axes[1].set_ylabel('Macro-F1 Score', fontsize=12)
axes[1].set_title('Few-Shot Learning: Macro-F1 vs k', fontsize=14, fontweight='bold')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Plot 2: Comparison across all experiments
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

experiments = ['Zero-shot', 'Few-shot\n(k=20)', 'Full Fine-tune']
x_pos = np.arange(len(experiments))
width = 0.25

# Accuracy comparison
for i, clf_name in enumerate(classifiers):
    accs = [
        zero_shot_results[clf_name]['accuracy'],
        few_shot_k20[clf_name]['accuracy'],
        full_finetune_results[clf_name]['accuracy']
    ]
    axes[0].bar(x_pos + i*width, accs, width, label=clf_name, alpha=0.8)

axes[0].set_xlabel('Experiment Type', fontsize=12)
axes[0].set_ylabel('Accuracy', fontsize=12)
axes[0].set_title('Accuracy Comparison Across Experiments', fontsize=14, fontweight='bold')
axes[0].set_xticks(x_pos + width)
axes[0].set_xticklabels(experiments)
axes[0].legend()
axes[0].grid(True, alpha=0.3, axis='y')

# Macro-F1 comparison
for i, clf_name in enumerate(classifiers):
    f1s = [
        zero_shot_results[clf_name]['macro_f1'],
        few_shot_k20[clf_name]['macro_f1'],
        full_finetune_results[clf_name]['macro_f1']
    ]
    axes[1].bar(x_pos + i*width, f1s, width, label=clf_name, alpha=0.8)

axes[1].set_xlabel('Experiment Type', fontsize=12)
axes[1].set_ylabel('Macro-F1 Score', fontsize=12)
axes[1].set_title('Macro-F1 Comparison Across Experiments', fontsize=14, fontweight='bold')
axes[1].set_xticks(x_pos + width)
axes[1].set_xticklabels(experiments)
axes[1].legend()
axes[1].grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Confusion Matrices

# %%
# Get zero-shot predictions for confusion matrices
_, _, cm_rf_zs, preds_rf_zs = zero_shot_baseline(
    RandomForestClassifier(n_estimators=500, n_jobs=-1, random_state=42),
    X_gtzan_flat, y_gtzan, X_esc_flat, y_esc, return_all_metrics=True
)

_, _, cm_lr_zs, preds_lr_zs = zero_shot_baseline(
    LogisticRegression(max_iter=2000, n_jobs=-1, random_state=42),
    X_gtzan_flat, y_gtzan, X_esc_flat, y_esc, return_all_metrics=True
)

_, _, cm_ridge_zs, preds_ridge_zs = zero_shot_baseline(
    RidgeClassifier(alpha=1.0, random_state=42),
    X_gtzan_flat, y_gtzan, X_esc_flat, y_esc, return_all_metrics=True
)

# Plot confusion matrices
fig, axes = plt.subplots(2, 3, figsize=(18, 12))

# Zero-shot confusion matrices
cms_zs = [cm_rf_zs, cm_lr_zs, cm_ridge_zs]
clf_names_short = ['RF', 'LR', 'Ridge']

for i, (cm, name) in enumerate(zip(cms_zs, clf_names_short)):
    # Normalize confusion matrix
    cm_norm = cm.astype('float') / (cm.sum(axis=1)[:, np.newaxis] + 1e-10)  # Add small epsilon to avoid division by zero

    sns.heatmap(cm_norm, annot=False, fmt='.2f', cmap='Blues', ax=axes[0, i],
                cbar_kws={'label': 'Normalized Count'}, vmin=0, vmax=1)
    axes[0, i].set_title(f'Zero-shot: {name}', fontsize=12, fontweight='bold')
    axes[0, i].set_xlabel('Predicted Label', fontsize=10)
    axes[0, i].set_ylabel('True Label', fontsize=10)

# Full fine-tuning confusion matrices
cms_full = [cm_rf_full, cm_lr_full, cm_ridge_full]

for i, (cm, name) in enumerate(zip(cms_full, clf_names_short)):
    # Normalize confusion matrix
    cm_norm = cm.astype('float') / (cm.sum(axis=1)[:, np.newaxis] + 1e-10)

    sns.heatmap(cm_norm, annot=False, fmt='.2f', cmap='Greens', ax=axes[1, i],
                cbar_kws={'label': 'Normalized Count'}, vmin=0, vmax=1)
    axes[1, i].set_title(f'Full Fine-tune: {name}', fontsize=12, fontweight='bold')
    axes[1, i].set_xlabel('Predicted Label', fontsize=10)
    axes[1, i].set_ylabel('True Label', fontsize=10)

plt.suptitle('Confusion Matrices: Zero-shot vs Full Fine-tuning', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

print("\nNote: Confusion matrices show normalized values (proportions).")
print("For 50 classes, individual cells may be small. Focus on diagonal patterns.")
# Out:
# Note: Confusion matrices show normalized values (proportions).
# For 50 classes, individual cells may be small. Focus on diagonal patterns.

# %% [markdown]
# ## Detailed Results Table

# %%
# Create detailed results table for all k values
detailed_results = []

for clf_name, results_dict in zip(['Random Forest', 'Logistic Regression', 'Ridge'],
                                   [rf_few, lr_few, ridge_few]):
    # Zero-shot
    detailed_results.append({
        'Classifier': clf_name,
        'Experiment': 'Zero-shot',
        'k': 0,
        'Accuracy': zero_shot_results[clf_name]['accuracy'],
        'Macro-F1': zero_shot_results[clf_name]['macro_f1']
    })

    # Few-shot for each k
    for k in sorted(results_dict.keys()):
        detailed_results.append({
            'Classifier': clf_name,
            'Experiment': 'Few-shot',
            'k': k,
            'Accuracy': results_dict[k]['accuracy'],
            'Macro-F1': results_dict[k]['macro_f1']
        })

    # Full fine-tuning
    detailed_results.append({
        'Classifier': clf_name,
        'Experiment': 'Full Fine-tune',
        'k': 'all',
        'Accuracy': full_finetune_results[clf_name]['accuracy'],
        'Macro-F1': full_finetune_results[clf_name]['macro_f1']
    })

detailed_df = pd.DataFrame(detailed_results)
print("\n" + "=" * 80)
print("DETAILED RESULTS")
print("=" * 80)
print(detailed_df.to_string(index=False))
# Out:
# ================================================================================
# DETAILED RESULTS
# ================================================================================
#          Classifier     Experiment   k  Accuracy  Macro-F1
#       Random Forest      Zero-shot   0  0.024500  0.006870
#       Random Forest       Few-shot   1  0.350256  0.334147
#       Random Forest       Few-shot   5  0.683429  0.670911
#       Random Forest       Few-shot  10  0.776000  0.772360
#       Random Forest       Few-shot  20  0.855000  0.853055
#       Random Forest Full Fine-tune all  0.865000  0.864687
# Logistic Regression      Zero-shot   0  0.040000  0.009652
# Logistic Regression       Few-shot   1  0.346667  0.355863
# Logistic Regression       Few-shot   5  0.716000  0.713929
# Logistic Regression       Few-shot  10  0.784667  0.786654
# Logistic Regression       Few-shot  20  0.843000  0.843666
# Logistic Regression Full Fine-tune all  0.857500  0.856379
#               Ridge      Zero-shot   0  0.012000  0.004036
#               Ridge       Few-shot   1  0.080000  0.070381
#               Ridge       Few-shot   5  0.547429  0.573914
#               Ridge       Few-shot  10  0.750667  0.753907
#               Ridge       Few-shot  20  0.820000  0.819252
#               Ridge Full Fine-tune all  0.847500  0.847158

# %% [markdown]
# ## Summary
#
# This notebook implements three transfer learning experiments:
#
# 1. **Zero-shot**: Train classifier on GTZAN (music genres), test on ESC-50 (environmental sounds)
# 2. **Few-shot**: Train on GTZAN + k samples per class from ESC-50, test on remaining ESC-50 samples
# 3. **Full Fine-tuning**: Train classifier on all ESC-50 data (upper bound performance)
#
# ### Key Results to Report:
# - **Zero-shot performance**: Shows baseline generalization from music to environmental sounds
# - **Few-shot learning curves**: Performance improvement as k increases (k=1, 5, 10, 20)
# - **Full fine-tuning**: Upper bound showing best possible performance
# - **Confusion matrices**: Visualize which classes are confused with each other
# - **Macro-F1 scores**: Important for imbalanced datasets (all classes weighted equally)
#
# ### Next Steps:
# 1. Run all cells sequentially
# 2. Review the summary tables and visualizations
# 3. Analyze confusion matrices to identify which sound categories are most confused
# 4. Compare performance across classifiers (Random Forest, Logistic Regression, Ridge)
# 5. Document findings in your report/poster
